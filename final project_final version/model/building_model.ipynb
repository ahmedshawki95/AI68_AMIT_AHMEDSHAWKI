# %%
import random
import json
import pickle
import numpy as np
import tensorflow as tf
import nltk
from nltk.stem import WordNetLemmatizer

lemmatizer=WordNetLemmatizer()

intents= json.loads(open(r'C:\Users\workstation\OneDrive - Alexandria University\AI\final project\final version\intents.json', 'r', encoding='utf-8').read())

words=[]
classes=[]
documents=[]
ignoreLetters=['/','!','.',',']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        wordList=nltk.word_tokenize(pattern)
        words.extend(wordList)
        documents.append((wordList,intent['label']))
        if intent['label'] not in classes:
            classes.append(intent['label'])

words=[lemmatizer.lemmatize(word) for word in words if word not in ignoreLetters]
words=sorted(set(words))

classes=sorted(set(classes))

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

training = []
outputEmpty = [0] * len(classes)

for document in documents:
    bag = []
    wordPatterns = document[0]
    wordPatterns = [lemmatizer.lemmatize(word.lower()) for word in wordPatterns]
    for word in words:
        bag.append(1) if word in wordPatterns else bag.append(0)

    outputRow = list(outputEmpty)
    outputRow[classes.index(document[1])] = 1
    training.append(bag + outputRow)

random.shuffle(training)
training = np.array(training)

trainX = training[:, :len(words)]
trainY = training[:, len(words):]

model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(264, input_shape=(len(trainX[0]),), activation = 'tanh'))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Dense(128, activation = 'tanh'))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Dense(128, activation = 'tanh'))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Dense(64, activation = 'tanh'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(len(trainY[0]), activation='softmax'))

sgd = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

hist = model.fit(np.array(trainX), np.array(trainY), epochs=50, batch_size=16, verbose=1)
model.save('chatbot_model.keras', hist)
print('Done')

from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

predictions = model.predict(trainX)

# Convert one-hot encoded predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Convert one-hot encoded true labels to class labels
true_labels = np.argmax(trainY, axis=1)

# Calculate precision, recall, F1-score, and accuracy
precision = precision_score(true_labels, predicted_labels, average='weighted')
recall = recall_score(true_labels, predicted_labels, average='weighted')
f1 = f1_score(true_labels, predicted_labels, average='weighted')
accuracy = accuracy_score(true_labels, predicted_labels)
# Print the metrics
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("Accuracy:", accuracy)
# Out:
# Epoch 1/50
# c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0598 - loss: 5.2459
# Epoch 2/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2136 - loss: 4.1783
# Epoch 3/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2526 - loss: 3.8957
# Epoch 4/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2651 - loss: 3.8046
# Epoch 5/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3135 - loss: 3.4816
# Epoch 6/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3240 - loss: 3.3934
# Epoch 7/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3286 - loss: 3.2996
# Epoch 8/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3380 - loss: 3.2091
# Epoch 9/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3710 - loss: 3.0401
# Epoch 10/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3965 - loss: 2.9079
# Epoch 11/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4281 - loss: 2.7402
# Epoch 12/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4286 - loss: 2.6928
# Epoch 13/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4230 - loss: 2.6064
# Epoch 14/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4854 - loss: 2.4243
# Epoch 15/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4886 - loss: 2.2632
# Epoch 16/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5109 - loss: 2.1630
# Epoch 17/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5495 - loss: 2.0479
# Epoch 18/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5724 - loss: 1.9186
# Epoch 19/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5912 - loss: 1.8750
# Epoch 20/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6103 - loss: 1.7133
# Epoch 21/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6414 - loss: 1.7205
# Epoch 22/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7002 - loss: 1.5350
# Epoch 23/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6962 - loss: 1.4392
# Epoch 24/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7367 - loss: 1.3110
# Epoch 25/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7177 - loss: 1.3095
# Epoch 26/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7543 - loss: 1.2159
# Epoch 27/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7516 - loss: 1.1474
# Epoch 28/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7604 - loss: 1.1314
# Epoch 29/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7867 - loss: 1.0532
# Epoch 30/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7939 - loss: 1.0352
# Epoch 31/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7830 - loss: 1.0205
# Epoch 32/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8026 - loss: 0.9470
# Epoch 33/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8032 - loss: 0.9441
# Epoch 34/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8226 - loss: 0.8793
# Epoch 35/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8359 - loss: 0.8128
# Epoch 36/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8540 - loss: 0.7786
# Epoch 37/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8390 - loss: 0.7907
# Epoch 38/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8688 - loss: 0.6953
# Epoch 39/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8628 - loss: 0.6957
# Epoch 40/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8554 - loss: 0.6929
# Epoch 41/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8880 - loss: 0.6252
# Epoch 42/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8615 - loss: 0.6401
# Epoch 43/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8743 - loss: 0.5922
# Epoch 44/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8941 - loss: 0.5894
# Epoch 45/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9139 - loss: 0.5365
# Epoch 46/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8979 - loss: 0.5521
# Epoch 47/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8822 - loss: 0.5237
# Epoch 48/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8845 - loss: 0.5347
# Epoch 49/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9086 - loss: 0.4898
# Epoch 50/50
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9142 - loss: 0.5262
# Done
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Precision: 0.9759479512735326
# Recall: 0.9683720930232558
# F1-score: 0.9675138840477264
# Accuracy: 0.9683720930232558
