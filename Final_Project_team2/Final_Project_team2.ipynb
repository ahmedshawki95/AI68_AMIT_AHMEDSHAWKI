# %% [markdown]
# ![image.png](attachment:image.png)
#  # Deep Learning Final Project

# %% [markdown]
# This final project conclusively proves your understanding and comprehension of each part of the explanation, so you must perform all the following tasks to confirm your understanding and knowledge of each topic.

# %% [markdown]
# #### In this exceptional project, we will cover all topics related to deep learning. Therefore, it’s important to study carefully and answer each section thoroughly to demonstrate your understanding of the module. The final part is optional, but it’s highly encouraged if you make an effort to complete it. We will discuss the project in our upcoming lectures with each individual to ensure a comprehensive understanding of this extensive subject.

# %% [markdown]
# To assess your understanding we use a popular dataset called MNIST
# - The MNIST dataset (Modified National Institute of Standards and Technology) is one of the most well-known datasets in the field of machine learning and computer vision. It consists of:
#
# - Images:
#
# 60,000 training images and 10,000 test images.
# Each image is a 28x28 grayscale image representing a handwritten digit (0-9).
# The pixel values range from 0 (black) to 255 (white).
# - Labels:
#
# Each image has a corresponding label indicating which digit (0-9) it represents.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# for  every project

# %%
# import Libraries
import numpy as np
from sklearn.metrics import accuracy_score
from matplotlib import pyplot as plt
# %matplotlib inline
import tensorflow as tf
print("We're using TF", tf.__version__)
import sys
sys.path.append("../..")
# import matplotlib_utils
from importlib import reload
from sklearn.model_selection import ParameterGrid

#from keras.wrappers.scikit_learn import KerasClassifier
from scikeras.wrappers import KerasClassifier, KerasRegressor

from tqdm import tqdm
# Out:
# We're using TF 2.17.0

# %% [markdown]
# # Look at the data
#
# In this task we have 50000 28x28 images of digits from 0 to 9.
# We will train a classifier on this data.

# %%
from tensorflow.keras.datasets import mnist
from sklearn.model_selection import train_test_split

(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
fig, ax = plt.subplots(figsize=(2, 2))  # Set figure size (width, height) in inches

# Display a sample patch from the image
print("X_train [shape %s] sample patch:\n" % (str(X_train.shape)), X_train[1, 15:20, 5:10])
print("A closeup of a sample patch:")
ax.imshow(X_train[1, 15:20, 5:10], cmap="Greys")
ax.set_title("Sample Patch (15:20, 5:10)")
ax.axis('off')  # Hide the axes
plt.show()

# Display the whole sample image with a different size
fig, ax = plt.subplots(figsize=(2, 2))  # Adjust the size as needed
print("And the whole sample:")
ax.imshow(X_train[1], cmap="Greys")
ax.set_title("Whole Sample Image")
ax.axis('off')  # Hide the axes
plt.show()

# Display the y_train values
print("y_train [shape %s] 10 samples:\n" % (str(y_train.shape)), y_train[:10])
# Out:
# X_train [shape (48000, 28, 28)] sample patch:
#  [[  0  77 254 154   0]
#  [  0 145 253  96   0]
#  [  0 254 238  37   0]
#  [  0 254 229   0   0]
#  [  0 254 246  69   0]]
# A closeup of a sample patch:
# And the whole sample:
# y_train [shape (48000,)] 10 samples:
#  [5 0 1 6 1 3 8 8 1 8]

# %% [markdown]
# # Load and preprocess the MNIST dataset

# %%
import tensorflow as tf

# Load and preprocess the MNIST dataset
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()

# Preprocess data (normalize)
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# %% [markdown]
# # Flatten the images (28x28 -> 784)

# %%
X_train = X_train.reshape(-1, 784)
X_test = X_test.reshape(-1, 784)

# %% [markdown]
# # One-hot encode labels

# %%
y_train_oh = tf.keras.utils.to_categorical(y_train, 10)
y_test_oh = tf.keras.utils.to_categorical(y_test, 10)

# %% [markdown]
# # Define a function to create and compile the model

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Define a function to create and compile the model
def create_model(optimizer='adam', learning_rate=0.01):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(5, activation='sigmoid', input_shape=(784,)),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    opt = tf.keras.optimizers.get(optimizer)
    opt.learning_rate = learning_rate
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Create the model using the function
model = create_model(optimizer='adam', learning_rate=0.001)

# Train the model
history = model.fit(X_train, y_train_oh, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(X_test, y_test_oh)
print(f"Test accuracy: {test_acc}")
# Out:
# Epoch 1/10
# c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5016 - loss: 1.8353 - val_accuracy: 0.7291 - val_loss: 1.1446
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7399 - loss: 1.0582 - val_accuracy: 0.7926 - val_loss: 0.8393
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7900 - loss: 0.8223 - val_accuracy: 0.8159 - val_loss: 0.7108
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8117 - loss: 0.7073 - val_accuracy: 0.8273 - val_loss: 0.6464
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8219 - loss: 0.6546 - val_accuracy: 0.8402 - val_loss: 0.5982
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8313 - loss: 0.6129 - val_accuracy: 0.8414 - val_loss: 0.5749
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8375 - loss: 0.5859 - val_accuracy: 0.8450 - val_loss: 0.5552
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8425 - loss: 0.5613 - val_accuracy: 0.8487 - val_loss: 0.5381
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8451 - loss: 0.5445 - val_accuracy: 0.8522 - val_loss: 0.5232
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8495 - loss: 0.5240 - val_accuracy: 0.8562 - val_loss: 0.5100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8278 - loss: 0.5660
# Test accuracy: 0.8479999899864197

# %% [markdown]
# #### Put here the accuracy of the basic model
# | Accuracy         | 0.8655999898910522   |
# |--------------|----------------|
#  #### Give me the reson for this result

# %% [markdown]
# # Gride search algorithm to choose the best parameters

# %% [markdown]
# for code below try to choose another papmeters and try to built all avalaible parameters

# %%
import tensorflow as tf
#from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from scikeras.wrappers import KerasClassifier, KerasRegressor

from sklearn.model_selection import GridSearchCV
from tqdm import tqdm


# Define a function to create and compile the model
def create_model(optimizer='adam', learning_rate=0.1):
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(5, activation='sigmoid', input_shape=(784,)),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    opt = tf.keras.optimizers.get(optimizer)
    opt.learning_rate = learning_rate
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Wrap the model using KerasClassifier
model = KerasClassifier(build_fn=create_model, verbose=0)

param_grid = {
    'batch_size': [500,1000,2000,3000,5000],            # Different batch sizes
    'epochs': [5,10,20],                     # Different number of epochs
    'model__optimizer': ['adam','rmsprop'],  # Different optimizers with proper prefix
    'model__learning_rate': [ 0.01,0.001]  # Different learning rates with proper prefix
}

# Initialize the GridSearchCV object
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)

# Fit the grid search and wrap with progress bar
with tqdm(total=len(param_grid['batch_size']) * len(param_grid['epochs']), desc="Grid Search Progress", unit="iteration") as pbar:
    grid_result = grid.fit(X_train, y_train_oh)
    pbar.update(1)

# Use cv_results_ instead of the deprecated grid_scores_
print(f"Best score: {grid_result.best_score_} using {grid_result.best_params_}")

# Display the cross-validation results
for mean, std, params in zip(grid_result.cv_results_['mean_test_score'], grid_result.cv_results_['std_test_score'], grid_result.cv_results_['params']):
    print(f"Mean: {mean:.4f}, Std: {std:.4f}, Params: {params}")

# Evaluate the best model on the test set
best_model = grid_result.best_estimator_
test_loss, test_acc = best_model.model_.evaluate(X_test, y_test_oh)  # Use `model_` to access the underlying Keras model
print(f"Test Accuracy: {test_acc}")
# Out:
# Grid Search Progress:   0%|          | 0/15 [00:00<?, ?iteration/s]c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\scikeras\wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Grid Search Progress:   7%|▋         | 1/15 [06:00<1:24:02, 360.15s/iteration]
# Best score: 0.8727666666666667 using {'batch_size': 500, 'epochs': 10, 'model__learning_rate': 0.01, 'model__optimizer': 'rmsprop'}
# Mean: 0.8315, Std: 0.0140, Params: {'batch_size': 500, 'epochs': 5, 'model__learning_rate': 0.01, 'model__optimizer': 'adam'}
# Mean: 0.8416, Std: 0.0078, Params: {'batch_size': 500, 'epochs': 5, 'model__learning_rate': 0.01, 'model__optimizer': 'rmsprop'}
# Mean: 0.6804, Std: 0.0249, Params: {'batch_size': 500, 'epochs': 5, 'model__learning_rate': 0.001, 'model__optimizer': 'adam'}
# Mean: 0.6391, Std: 0.0069, Params: {'batch_size': 500, 'epochs': 5, 'model__learning_rate': 0.001, 'model__optimizer': 'rmsprop'}
# Mean: 0.8647, Std: 0.0036, Params: {'batch_size': 500, 'epochs': 10, 'model__learning_rate': 0.01, 'model__optimizer': 'adam'}
# Mean: 0.8728, Std: 0.0061, Params: {'batch_size': 500, 'epochs': 10, 'model__learning_rate': 0.01, 'model__optimizer': 'rmsprop'}
# Mean: 0.7522, Std: 0.0256, Params: {'batch_size': 500, 'epochs': 10, 'model__learning_rate': 0.001, 'model__optimizer': 'adam'}
# Mean: 0.7438, Std: 0.0273, Params: {'batch_size': 500, 'epochs': 10, 'model__learning_rate': 0.001, 'model__optimizer': 'rmsprop'}
# Mean: 0.8577, Std: 0.0030, Params: {'batch_size': 500, 'epochs': 20, 'model__learning_rate': 0.01, 'model__optimizer': 'adam'}
# Mean: 0.8665, Std: 0.0070, Params: {'batch_size': 500, 'epochs': 20, 'model__learning_rate': 0.01, 'model__optimizer': 'rmsprop'}
# Mean: 0.7964, Std: 0.0347, Params: {'batch_size': 500, 'epochs': 20, 'model__learning_rate': 0.001, 'model__optimizer': 'adam'}
# Mean: 0.8088, Std: 0.0210, Params: {'batch_size': 500, 'epochs': 20, 'model__learning_rate': 0.001, 'model__optimizer': 'rmsprop'}
# Mean: 0.8154, Std: 0.0071, Params: {'batch_size': 1000, 'epochs': 5, 'model__learning_rate': 0.01, 'model__optimizer': 'adam'}
# Mean: 0.8254, Std: 0.0125, Params: {'batch_size': 1000, 'epochs': 5, 'model__learning_rate': 0.01, 'model__optimizer': 'rmsprop'}
# Mean: 0.5375, Std: 0.0331, Params: {'batch_size': 1000, 'epochs': 5, 'model__learning_rate': 0.001, 'model__optimizer': 'adam'}
# Mean: 0.5325, Std: 0.0260, Params: {'batch_size': 1000, 'epochs': 5, 'model__learning_rate': 0.001, 'model__optimizer': 'rmsprop'}
# Mean: 0.8406, Std: 0.0110, Params: {'batch_size': 1000, 'epochs': 10, 'model__learning_rate': 0.01, 'model__optimizer': 'adam'}
# Mean: 0.8481, Std: 0.0111, Params: {'batch_size': 1000, 'epochs': 10, 'model__learning_rate': 0.01, 'model__optimizer': 'rmsprop'}
# Mean: 0.6637, Std: 0.0036, Params: {'batch_size': 1000, 'epochs': 10, 'model__learning_rate': 0.001, 'model__optimizer': 'adam'}
# Mean: 0.6411, Std: 0.0338, Params: {'batch_size': 1000, 'epochs': 10, 'model__learning_rate': 0.001, 'model__optimizer': 'rmsprop'}
# Mean: 0.8691, Std: 0.0057, Params: {'batch_size': 1000, 'epochs': 20, 'model__learning_rate': 0.01, 'model__optimizer': 'adam'}
# Mean: 0.8579, Std: 0.0070, Params: {'batch_size': 1000, 'epochs': 20, 'model__learning_rate': 0.01, 'model__optimizer': 'rmsprop'}
# Mean: 0.7571, Std: 0.0260, Params: {'batch_size': 1000, 'epochs': 20, 'model__learning_rate': 0.001, 'model__optimizer': 'adam'}
# Mean: 0.7470, Std: 0.0098, Params: {'batch_size': 1000, 'epochs': 20, 'model__learning_rate': 0.001, 'model__optimizer': 'rmsprop'}
# Mean: 0.7826, Std: 0.0133, Params: {'batch_size': 2000, 'epochs': 5, 'model__learning_rate': 0.01, 'model__optimizer': 'adam'}
# Mean: 0.8065, Std: 0.0052, Params: {'batch_size': 2000, 'epochs': 5, 'model__learning_rate': 0.01, 'model__optimizer': 'rmsprop'}
# Mean: 0.3348, Std: 0.0715, Params: {'batch_size': 2000, 'epochs': 5, 'model__learning_rate': 0.001, 'model__optimizer': 'adam'}
# Mean: 0.4373, Std: 0.0105, Params: {'batch_size': 2000, 'epochs': 5, 'model__learning_rate': 0.001, 'model__optimizer': 'rmsprop'}
# Mean: 0.7665, Std: 0.0444, Params: {'batch_size': 2000, 'epochs': 10, 'model__learning_rate': 0.01, 'model__optimizer': 'adam'}
# Mean: 0.8012, Std: 0.0337, Params: {'batch_size': 2000, 'epochs': 10, 'model__learning_rate': 0.01, 'model__optimizer': 'rmsprop'}
# Mean: 0.5564, Std: 0.0218, Params: {'batch_size': 2000, 'epochs': 10, 'model__learning_rate': 0.001, 'model__optimizer': 'adam'}
# Mean: 0.5818, Std: 0.0088, Params: {'batch_size': 2000, 'epochs': 10, 'model__learning_rate': 0.001, 'model__optimizer': 'rmsprop'}
# Mean: 0.8592, Std: 0.0027, Params: {'batch_size': 2000, 'epochs': 20, 'model__learning_rate': 0.01, 'model__optimizer': 'adam'}
# Mean: 0.8636, Std: 0.0017, Params: {'batch_size': 2000, 'epochs': 20, 'model__learning_rate': 0.01, 'model__optimizer': 'rmsprop'}
# Mean: 0.6751, Std: 0.0196, Params: {'batch_size': 2000, 'epochs': 20, 'model__learning_rate': 0.001, 'model__optimizer': 'adam'}
# Mean: 0.6599, Std: 0.0260, Params: {'batch_size': 2000, 'epochs': 20, 'model__learning_rate': 0.001, 'model__optimizer': 'rmsprop'}
# Mean: 0.7367, Std: 0.0245, Params: {'batch_size': 3000, 'epochs': 5, 'model__learning_rate': 0.01, 'model__optimizer': 'adam'}
# Mean: 0.7698, Std: 0.0239, Params: {'batch_size': 3000, 'epochs': 5, 'model__learning_rate': 0.01, 'model__optimizer': 'rmsprop'}
# Mean: 0.3357, Std: 0.0689, Params: {'batch_size': 3000, 'epochs': 5, 'model__learning_rate': 0.001, 'model__optimizer': 'adam'}
# Mean: 0.3321, Std: 0.0435, Params: {'batch_size': 3000, 'epochs': 5, 'model__learning_rate': 0.001, 'model__optimizer': 'rmsprop'}
# Mean: 0.7868, Std: 0.0236, Params: {'batch_size': 3000, 'epochs': 10, 'model__learning_rate': 0.01, 'model__optimizer': 'adam'}
# Mean: 0.7995, Std: 0.0198, Params: {'batch_size': 3000, 'epochs': 10, 'model__learning_rate': 0.01, 'model__optimizer': 'rmsprop'}
# Mean: 0.4899, Std: 0.0281, Params: {'batch_size': 3000, 'epochs': 10, 'model__learning_rate': 0.001, 'model__optimizer': 'adam'}
# Mean: 0.4807, Std: 0.0576, Params: {'batch_size': 3000, 'epochs': 10, 'model__learning_rate': 0.001, 'model__optimizer': 'rmsprop'}
# Mean: 0.8441, Std: 0.0051, Params: {'batch_size': 3000, 'epochs': 20, 'model__learning_rate': 0.01, 'model__optimizer': 'adam'}
# Mean: 0.8402, Std: 0.0060, Params: {'batch_size': 3000, 'epochs': 20, 'model__learning_rate': 0.01, 'model__optimizer': 'rmsprop'}
# Mean: 0.6043, Std: 0.0312, Params: {'batch_size': 3000, 'epochs': 20, 'model__learning_rate': 0.001, 'model__optimizer': 'adam'}
# Mean: 0.6433, Std: 0.0065, Params: {'batch_size': 3000, 'epochs': 20, 'model__learning_rate': 0.001, 'model__optimizer': 'rmsprop'}
# Mean: 0.6383, Std: 0.0513, Params: {'batch_size': 5000, 'epochs': 5, 'model__learning_rate': 0.01, 'model__optimizer': 'adam'}
# Mean: 0.6823, Std: 0.0263, Params: {'batch_size': 5000, 'epochs': 5, 'model__learning_rate': 0.01, 'model__optimizer': 'rmsprop'}
# Mean: 0.2716, Std: 0.0451, Params: {'batch_size': 5000, 'epochs': 5, 'model__learning_rate': 0.001, 'model__optimizer': 'adam'}
# Mean: 0.2653, Std: 0.1134, Params: {'batch_size': 5000, 'epochs': 5, 'model__learning_rate': 0.001, 'model__optimizer': 'rmsprop'}
# Mean: 0.7426, Std: 0.0222, Params: {'batch_size': 5000, 'epochs': 10, 'model__learning_rate': 0.01, 'model__optimizer': 'adam'}
# Mean: 0.7571, Std: 0.0429, Params: {'batch_size': 5000, 'epochs': 10, 'model__learning_rate': 0.01, 'model__optimizer': 'rmsprop'}
# Mean: 0.2928, Std: 0.0289, Params: {'batch_size': 5000, 'epochs': 10, 'model__learning_rate': 0.001, 'model__optimizer': 'adam'}
# Mean: 0.4514, Std: 0.0379, Params: {'batch_size': 5000, 'epochs': 10, 'model__learning_rate': 0.001, 'model__optimizer': 'rmsprop'}
# Mean: 0.7819, Std: 0.0467, Params: {'batch_size': 5000, 'epochs': 20, 'model__learning_rate': 0.01, 'model__optimizer': 'adam'}
# Mean: 0.7984, Std: 0.0142, Params: {'batch_size': 5000, 'epochs': 20, 'model__learning_rate': 0.01, 'model__optimizer': 'rmsprop'}
# Mean: 0.4771, Std: 0.0646, Params: {'batch_size': 5000, 'epochs': 20, 'model__learning_rate': 0.001, 'model__optimizer': 'adam'}
# Mean: 0.5531, Std: 0.0356, Params: {'batch_size': 5000, 'epochs': 20, 'model__learning_rate': 0.001, 'model__optimizer': 'rmsprop'}
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8588 - loss: 0.5063
# Test Accuracy: 0.8715999722480774

# %% [markdown]
# - so kindly fill the table below to enhance your good choise

# %% [markdown]
# -parameters on grid search
# |epochs| batch_size | optimizer_1 | optimizer_2 | learning_rate_1 | learning_rate_2 |
# |------|------------|-------------|-------------|-----------------|-----------------|
# |5| 500        | adam        | rmsprop     | 0.001           | 0.01            |
# |10| 1000       | adam        | rmsprop     | 0.001           | 0.01            |
# |20| 2000       | adam        | rmsprop     | 0.001           | 0.01            |
# || 3000       | adam        | rmsprop     | 0.001           | 0.01            |
# || 5000       | adam        | rmsprop     | 0.001           | 0.01            |
#
# -

# %% [markdown]
#  print here the best paramerters give you the best accuracy regarding for archticture design above
# - | batch_size    | epochs    | optimizer | learning_rate      | Accueracy      |
#    |--------------|-----|-----|-----------------|-----------------|
#    |500|20|rmsprop|0.01|0.8717833333333332 |

# %% [markdown]
# - After you know the best optimizer and good Learning rate for the above archticture
# - please design your model and put here the final result

# %% [markdown]
# Here  i was converted squentional model into functional ApI Model
# - so re-design Your model by adding some hidden layer and change the activation function

# %%
import tensorflow as tf

# Define the Functional API model
def create_model(optimizer='adam', learning_rate=0.01):
    # Input layer
    inputs = tf.keras.Input(shape=(784,))
    
    # Hidden layer
    x = tf.keras.layers.Dense(1000, activation='relu')(inputs)
    # Hidden layer2
    x2 = tf.keras.layers.Dense(1000, activation='relu')(x)
    # Hidden layer2
    x3 = tf.keras.layers.Dense(1500, activation='relu')(x2)
    # Hidden layer2
    x4 = tf.keras.layers.Dense(1000, activation='relu')(x3)
    # Output layer
    outputs = tf.keras.layers.Dense(10, activation='softmax')(x4)
    
    # Create model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    
    # Configure the model
    opt = tf.keras.optimizers.get(optimizer)
    opt.learning_rate = learning_rate
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# Create the model using the Functional API
model = create_model(optimizer='adam', learning_rate=0.001)

# Train the model
history = model.fit(X_train, y_train_oh, epochs=48, batch_size=1000, validation_split=0.2)

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(X_test, y_test_oh)
print(f"Test accuracy: {test_acc}")
# Out:
# Epoch 1/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 345ms/step - accuracy: 0.7261 - loss: 0.8454 - val_accuracy: 0.9585 - val_loss: 0.1365
# Epoch 2/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 17s 345ms/step - accuracy: 0.9673 - loss: 0.1049 - val_accuracy: 0.9698 - val_loss: 0.0962
# Epoch 3/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 327ms/step - accuracy: 0.9846 - loss: 0.0531 - val_accuracy: 0.9752 - val_loss: 0.0851
# Epoch 4/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 16s 336ms/step - accuracy: 0.9908 - loss: 0.0318 - val_accuracy: 0.9753 - val_loss: 0.0861
# Epoch 5/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 326ms/step - accuracy: 0.9928 - loss: 0.0224 - val_accuracy: 0.9765 - val_loss: 0.0916
# Epoch 6/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 17s 349ms/step - accuracy: 0.9950 - loss: 0.0160 - val_accuracy: 0.9762 - val_loss: 0.0979
# Epoch 7/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 340ms/step - accuracy: 0.9950 - loss: 0.0148 - val_accuracy: 0.9776 - val_loss: 0.1058
# Epoch 8/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 381ms/step - accuracy: 0.9951 - loss: 0.0140 - val_accuracy: 0.9758 - val_loss: 0.1145
# Epoch 9/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 368ms/step - accuracy: 0.9944 - loss: 0.0159 - val_accuracy: 0.9767 - val_loss: 0.0981
# Epoch 10/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 16s 341ms/step - accuracy: 0.9975 - loss: 0.0091 - val_accuracy: 0.9774 - val_loss: 0.1101
# Epoch 11/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 322ms/step - accuracy: 0.9968 - loss: 0.0114 - val_accuracy: 0.9728 - val_loss: 0.1283
# Epoch 12/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 339ms/step - accuracy: 0.9963 - loss: 0.0107 - val_accuracy: 0.9700 - val_loss: 0.1439
# Epoch 13/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 16s 326ms/step - accuracy: 0.9964 - loss: 0.0113 - val_accuracy: 0.9783 - val_loss: 0.1047
# Epoch 14/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 321ms/step - accuracy: 0.9975 - loss: 0.0074 - val_accuracy: 0.9758 - val_loss: 0.1192
# Epoch 15/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 337ms/step - accuracy: 0.9971 - loss: 0.0086 - val_accuracy: 0.9783 - val_loss: 0.1099
# Epoch 16/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 17s 361ms/step - accuracy: 0.9984 - loss: 0.0053 - val_accuracy: 0.9787 - val_loss: 0.1164
# Epoch 17/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 17s 345ms/step - accuracy: 0.9978 - loss: 0.0064 - val_accuracy: 0.9767 - val_loss: 0.1215
# Epoch 18/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 17s 347ms/step - accuracy: 0.9962 - loss: 0.0112 - val_accuracy: 0.9758 - val_loss: 0.1201
# Epoch 19/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 330ms/step - accuracy: 0.9979 - loss: 0.0069 - val_accuracy: 0.9798 - val_loss: 0.1098
# Epoch 20/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 22s 358ms/step - accuracy: 0.9985 - loss: 0.0049 - val_accuracy: 0.9783 - val_loss: 0.1149
# Epoch 21/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 320ms/step - accuracy: 0.9979 - loss: 0.0073 - val_accuracy: 0.9775 - val_loss: 0.1150
# Epoch 22/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 17s 349ms/step - accuracy: 0.9970 - loss: 0.0106 - val_accuracy: 0.9765 - val_loss: 0.1108
# Epoch 23/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 16s 336ms/step - accuracy: 0.9989 - loss: 0.0046 - val_accuracy: 0.9798 - val_loss: 0.1076
# Epoch 24/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 17s 348ms/step - accuracy: 0.9991 - loss: 0.0029 - val_accuracy: 0.9813 - val_loss: 0.1039
# Epoch 25/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 17s 361ms/step - accuracy: 0.9990 - loss: 0.0033 - val_accuracy: 0.9793 - val_loss: 0.1098
# Epoch 26/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 341ms/step - accuracy: 0.9980 - loss: 0.0068 - val_accuracy: 0.9796 - val_loss: 0.1159
# Epoch 27/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 322ms/step - accuracy: 0.9974 - loss: 0.0080 - val_accuracy: 0.9772 - val_loss: 0.1237
# Epoch 28/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 16s 330ms/step - accuracy: 0.9985 - loss: 0.0054 - val_accuracy: 0.9783 - val_loss: 0.1123
# Epoch 29/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 325ms/step - accuracy: 0.9982 - loss: 0.0061 - val_accuracy: 0.9747 - val_loss: 0.1207
# Epoch 30/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 340ms/step - accuracy: 0.9976 - loss: 0.0069 - val_accuracy: 0.9787 - val_loss: 0.1093
# Epoch 31/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 348ms/step - accuracy: 0.9982 - loss: 0.0063 - val_accuracy: 0.9797 - val_loss: 0.1133
# Epoch 32/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 406ms/step - accuracy: 0.9983 - loss: 0.0053 - val_accuracy: 0.9764 - val_loss: 0.1289
# Epoch 33/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 365ms/step - accuracy: 0.9989 - loss: 0.0040 - val_accuracy: 0.9803 - val_loss: 0.1187
# Epoch 34/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 16s 338ms/step - accuracy: 0.9989 - loss: 0.0038 - val_accuracy: 0.9813 - val_loss: 0.1102
# Epoch 35/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 325ms/step - accuracy: 0.9991 - loss: 0.0033 - val_accuracy: 0.9798 - val_loss: 0.1206
# Epoch 36/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 16s 334ms/step - accuracy: 0.9989 - loss: 0.0040 - val_accuracy: 0.9797 - val_loss: 0.1213
# Epoch 37/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 329ms/step - accuracy: 0.9993 - loss: 0.0027 - val_accuracy: 0.9783 - val_loss: 0.1228
# Epoch 38/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 369ms/step - accuracy: 0.9989 - loss: 0.0032 - val_accuracy: 0.9787 - val_loss: 0.1208
# Epoch 39/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 353ms/step - accuracy: 0.9992 - loss: 0.0038 - val_accuracy: 0.9790 - val_loss: 0.1269
# Epoch 40/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 360ms/step - accuracy: 0.9994 - loss: 0.0022 - val_accuracy: 0.9798 - val_loss: 0.1084
# Epoch 41/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 17s 352ms/step - accuracy: 0.9995 - loss: 0.0014 - val_accuracy: 0.9817 - val_loss: 0.1119
# Epoch 42/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 17s 349ms/step - accuracy: 0.9997 - loss: 0.0010 - val_accuracy: 0.9806 - val_loss: 0.1202
# Epoch 43/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 327ms/step - accuracy: 0.9996 - loss: 0.0017 - val_accuracy: 0.9781 - val_loss: 0.1232
# Epoch 44/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 25s 411ms/step - accuracy: 0.9995 - loss: 0.0014 - val_accuracy: 0.9818 - val_loss: 0.1110
# Epoch 45/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 17s 355ms/step - accuracy: 0.9995 - loss: 0.0018 - val_accuracy: 0.9803 - val_loss: 0.1205
# Epoch 46/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 17s 353ms/step - accuracy: 0.9990 - loss: 0.0032 - val_accuracy: 0.9794 - val_loss: 0.1304
# Epoch 47/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 17s 361ms/step - accuracy: 0.9983 - loss: 0.0070 - val_accuracy: 0.9802 - val_loss: 0.1030
# Epoch 48/48
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 335ms/step - accuracy: 0.9971 - loss: 0.0105 - val_accuracy: 0.9770 - val_loss: 0.1383
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9721 - loss: 0.1545
# Test accuracy: 0.9757999777793884

# %%
import tensorflow as tf

# Define the Functional API model
def create_model(optimizer='adam', learning_rate=0.01):
    # Input layer
    inputs = tf.keras.Input(shape=(784,))
    
    # Hidden layer
    x = tf.keras.layers.Dense(100, activation='relu')(inputs)
    # Hidden layer2
    x1 = tf.keras.layers.Dense(100, activation='relu')(x)
    # Hidden layer2
    outputs = tf.keras.layers.Dense(10, activation='softmax')(x1)
    
    # Create model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    
    # Configure the model
    opt = tf.keras.optimizers.get(optimizer)
    opt.learning_rate = learning_rate
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# Create the model using the Functional API
model = create_model(optimizer='adam', learning_rate=0.001)

# Train the model
history = model.fit(X_train, y_train_oh, epochs=30, batch_size=48, validation_split=0.3)

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(X_test, y_test_oh,batch_size=5)
print(f"Test accuracy: {test_acc}")
# Out:
# Epoch 1/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8406 - loss: 0.5562 - val_accuracy: 0.9513 - val_loss: 0.1647
# Epoch 2/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9599 - loss: 0.1358 - val_accuracy: 0.9627 - val_loss: 0.1250
# Epoch 3/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9729 - loss: 0.0885 - val_accuracy: 0.9623 - val_loss: 0.1257
# Epoch 4/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9809 - loss: 0.0627 - val_accuracy: 0.9693 - val_loss: 0.1057
# Epoch 5/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9851 - loss: 0.0474 - val_accuracy: 0.9676 - val_loss: 0.1198
# Epoch 6/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9878 - loss: 0.0368 - val_accuracy: 0.9698 - val_loss: 0.1106
# Epoch 7/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9903 - loss: 0.0293 - val_accuracy: 0.9709 - val_loss: 0.1088
# Epoch 8/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9919 - loss: 0.0256 - val_accuracy: 0.9713 - val_loss: 0.1142
# Epoch 9/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9941 - loss: 0.0198 - val_accuracy: 0.9686 - val_loss: 0.1321
# Epoch 10/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9943 - loss: 0.0179 - val_accuracy: 0.9727 - val_loss: 0.1170
# Epoch 11/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9952 - loss: 0.0144 - val_accuracy: 0.9706 - val_loss: 0.1307
# Epoch 12/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9955 - loss: 0.0143 - val_accuracy: 0.9713 - val_loss: 0.1424
# Epoch 13/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9957 - loss: 0.0131 - val_accuracy: 0.9711 - val_loss: 0.1397
# Epoch 14/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9957 - loss: 0.0147 - val_accuracy: 0.9726 - val_loss: 0.1441
# Epoch 15/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9961 - loss: 0.0102 - val_accuracy: 0.9733 - val_loss: 0.1481
# Epoch 16/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9967 - loss: 0.0109 - val_accuracy: 0.9731 - val_loss: 0.1406
# Epoch 17/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9958 - loss: 0.0108 - val_accuracy: 0.9751 - val_loss: 0.1412
# Epoch 18/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9977 - loss: 0.0079 - val_accuracy: 0.9718 - val_loss: 0.1618
# Epoch 19/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9976 - loss: 0.0072 - val_accuracy: 0.9737 - val_loss: 0.1603
# Epoch 20/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9969 - loss: 0.0106 - val_accuracy: 0.9734 - val_loss: 0.1567
# Epoch 21/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9979 - loss: 0.0058 - val_accuracy: 0.9741 - val_loss: 0.1587
# Epoch 22/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9980 - loss: 0.0065 - val_accuracy: 0.9735 - val_loss: 0.1694
# Epoch 23/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9974 - loss: 0.0077 - val_accuracy: 0.9699 - val_loss: 0.1813
# Epoch 24/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9968 - loss: 0.0100 - val_accuracy: 0.9735 - val_loss: 0.1706
# Epoch 25/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9983 - loss: 0.0067 - val_accuracy: 0.9724 - val_loss: 0.1799
# Epoch 26/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9981 - loss: 0.0072 - val_accuracy: 0.9753 - val_loss: 0.1634
# Epoch 27/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9976 - loss: 0.0073 - val_accuracy: 0.9733 - val_loss: 0.1836
# Epoch 28/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9984 - loss: 0.0054 - val_accuracy: 0.9673 - val_loss: 0.2237
# Epoch 29/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9973 - loss: 0.0091 - val_accuracy: 0.9721 - val_loss: 0.1841
# Epoch 30/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9978 - loss: 0.0063 - val_accuracy: 0.9726 - val_loss: 0.2009
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9706 - loss: 0.1817
# Test accuracy: 0.9745000004768372

# %% [markdown]
# Total Samples: The MNIST dataset has 60,000 training samples.
#
# Batch Size: If your batch size is set to 40 (for example), each batch consists of 40 samples.
#
# Batches per Epoch: The total number of batches for an epoch is calculated by dividing the total number of samples by the batch size. For instance, with 60,000 samples and a batch size of 40:
#
# Epoch Iteration: During each epoch, the model goes through all the batches (1500 in this case), which means it sees all the training data once.

# %%
# Plot training & validation loss values
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_pred = model.predict(X_test)

# Convert predictions and true labels to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test_oh, axis=1)

# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=np.arange(10))
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# # Hints!!!!

# %% [markdown]
# Total batches = Total samples / Batch size = 10,000 / 32 ≈ 313 batches.

# %% [markdown]
# # Answer the below Questions

# %% [markdown]
# # Q1
# ### Why is the sigmoid function considered ineffective for hidden layers, and what are the benefits of using it in the output layer?

# %% [markdown]
# because it may cause vanishing because its derivative tends to be zero with icrease or decrease in value

# %% [markdown]
# # Q2: For your enhanced model, please use the grid search algorithm to explore various optimization algorithms. Provide a brief description of each type and then list the best one in the table below.

# %%
import tensorflow as tf
#from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from scikeras.wrappers import KerasClassifier, KerasRegressor

from sklearn.model_selection import GridSearchCV
from tqdm import tqdm


# Define a function to create and compile the model
def create_model(optimizer='adam', learning_rate=0.01):
    # Input layer
    inputs = tf.keras.Input(shape=(784,))
    
    # Hidden layer
    x = tf.keras.layers.Dense(100, activation='relu')(inputs)
    # Hidden layer2
    x1 = tf.keras.layers.Dense(100, activation='relu')(x)
    # Hidden layer2
    outputs = tf.keras.layers.Dense(10, activation='softmax')(x1)
    
    # Create model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    
    # Configure the model
    opt = tf.keras.optimizers.get(optimizer)
    opt.learning_rate = learning_rate
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# Wrap the model using KerasClassifier
model = KerasClassifier(build_fn=create_model, verbose=0)

param_grid = {
    'batch_size': [48],            # Different batch sizes
    'epochs': [30],                     # Different number of epochs
    'model__optimizer': ['SGD','Momentum','rmsprop','AdaDelta','Adagrad','adam'],  # Different optimizers with proper prefix
    'model__learning_rate': [ 0.001]  # Different learning rates with proper prefix
}

# Initialize the GridSearchCV object
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)

# Fit the grid search and wrap with progress bar
with tqdm(total=len(param_grid['batch_size']) * len(param_grid['epochs']), desc="Grid Search Progress", unit="iteration") as pbar:
    grid_result = grid.fit(X_train, y_train_oh)
    pbar.update(1)

# Use cv_results_ instead of the deprecated grid_scores_
print(f"Best score: {grid_result.best_score_} using {grid_result.best_params_}")

# Display the cross-validation results
for mean, std, params in zip(grid_result.cv_results_['mean_test_score'], grid_result.cv_results_['std_test_score'], grid_result.cv_results_['params']):
    print(f"Mean: {mean:.4f}, Std: {std:.4f}, Params: {params}")

# Evaluate the best model on the test set
best_model = grid_result.best_estimator_
test_loss, test_acc = best_model.model_.evaluate(X_test, y_test_oh)  # Use `model_` to access the underlying Keras model
print(f"Test Accuracy: {test_acc}")
# Out:
# Grid Search Progress:   0%|          | 0/1 [00:00<?, ?iteration/s]c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 3 fits failed out of a total of 18.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\scikeras\wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\scikeras\wrappers.py", line 770, in fit
#     self._fit(
#   File "c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\scikeras\wrappers.py", line 925, in _fit
#     X, y = self._initialize(X, y)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\scikeras\wrappers.py", line 862, in _initialize
#     self.model_ = self._build_keras_model()
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\scikeras\wrappers.py", line 433, in _build_keras_model
#     model = final_build_fn(**build_params)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\workstation\AppData\Local\Temp\ipykernel_18192\530270876.py", line 25, in create_model
#   File "c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\optimizers\__init__.py", line 97, in get
#     raise ValueError(f"Could not interpret optimizer identifier: {identifier}")
# ValueError: Could not interpret optimizer identifier: Momentum
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [0.91226667        nan 0.9751     0.81751667 0.92098333 0.97275   ]
#   warnings.warn(
# c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\scikeras\wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# Grid Search Progress: 100%|██████████| 1/1 [11:09<00:00, 669.59s/iteration]
# Best score: 0.9751 using {'batch_size': 48, 'epochs': 30, 'model__learning_rate': 0.001, 'model__optimizer': 'rmsprop'}
# Mean: 0.9123, Std: 0.0028, Params: {'batch_size': 48, 'epochs': 30, 'model__learning_rate': 0.001, 'model__optimizer': 'SGD'}
# Mean: nan, Std: nan, Params: {'batch_size': 48, 'epochs': 30, 'model__learning_rate': 0.001, 'model__optimizer': 'Momentum'}
# Mean: 0.9751, Std: 0.0009, Params: {'batch_size': 48, 'epochs': 30, 'model__learning_rate': 0.001, 'model__optimizer': 'rmsprop'}
# Mean: 0.8175, Std: 0.0106, Params: {'batch_size': 48, 'epochs': 30, 'model__learning_rate': 0.001, 'model__optimizer': 'AdaDelta'}
# Mean: 0.9210, Std: 0.0016, Params: {'batch_size': 48, 'epochs': 30, 'model__learning_rate': 0.001, 'model__optimizer': 'Adagrad'}
# Mean: 0.9728, Std: 0.0015, Params: {'batch_size': 48, 'epochs': 30, 'model__learning_rate': 0.001, 'model__optimizer': 'adam'}
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9760 - loss: 0.2034
# Test Accuracy: 0.9801999926567078

# %% [markdown]
# | Optimizer   | Accuracy       |
# |-------------|----------------|
# | SGD         |     0.9123           |
# | Momentum    |     nan   (exploding)        |
# | RMSprop     |     0.9751           |
# | AdaDelta    |     0.8175           |
# | Adagrad     |      0.9210          |
# | Adam        |      0.9728          |
#
# -

# %% [markdown]
# # Q3: What is the main cause of the vanishing gradient problem, and how can we solve it?

# %% [markdown]
# the main cause of vanishsing is the low values of change in weights, we can solve it by using other activation function other than segmoid

# %% [markdown]
# ## "In the code below, the model is likely experiencing the vanishing gradient problem. Try to solve it in a separate cell."

# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.initializers import RandomNormal
w_init = RandomNormal(mean=1,stddev=1)
model_2 = Sequential()
model_2.add(Dense(128, activation= 'sigmoid', kernel_initializer =w_init , input_dim=28*28))
model_2.add(Dense(128, activation= 'sigmoid', kernel_initializer =w_init ))
model_2.add(Dense(10, activation= 'softmax', kernel_initializer =w_init))
model_2.compile(loss = 'sparse_categorical_crossentropy' , optimizer='adam' , metrics=['accuracy'])
model_2.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_76 (Dense)                │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_77 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_78 (Dense)                │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 118,282 (462.04 KB)
#  Trainable params: 118,282 (462.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history2=model_2.fit(X_train,y_train,epochs=10 , batch_size=128,validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.1064 - loss: 19.0468 - val_accuracy: 0.1060 - val_loss: 2.3063
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1073 - loss: 2.3047 - val_accuracy: 0.1060 - val_loss: 2.3100
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1032 - loss: 2.3060 - val_accuracy: 0.1060 - val_loss: 2.3102
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1098 - loss: 2.3071 - val_accuracy: 0.0995 - val_loss: 2.3059
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1053 - loss: 2.3076 - val_accuracy: 0.0989 - val_loss: 2.3152
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1089 - loss: 2.3068 - val_accuracy: 0.0956 - val_loss: 2.3131
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1049 - loss: 2.3077 - val_accuracy: 0.1060 - val_loss: 2.3165
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1080 - loss: 2.3077 - val_accuracy: 0.0975 - val_loss: 2.3095
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1017 - loss: 2.3079 - val_accuracy: 0.1060 - val_loss: 2.3161
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.1046 - loss: 2.3091 - val_accuracy: 0.1060 - val_loss: 2.3170

# %%
# Plot training & validation loss values
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history2.history['loss'], label='Training Loss')
plt.plot(history2.history['val_loss'], label='Validation Loss')
plt.title('model_2 Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history2.history['accuracy'], label='Training Accuracy')
plt.plot(history2.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')

plt.tight_layout()
plt.show()

# %%
#after changing activation fn to relu

from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.initializers import RandomNormal
w_init = RandomNormal(mean=1,stddev=1)
model_2 = Sequential()
model_2.add(Dense(128, activation= 'relu', kernel_initializer =w_init , input_dim=28*28))
model_2.add(Dense(128, activation= 'relu', kernel_initializer =w_init ))
model_2.add(Dense(10, activation= 'softmax', kernel_initializer =w_init))
model_2.compile(loss = 'sparse_categorical_crossentropy' , optimizer='adam' , metrics=['accuracy'])
model_2.summary()

history2=model_2.fit(X_train,y_train,epochs=10 , batch_size=128,validation_split=0.2)

# Plot training & validation loss values
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history2.history['loss'], label='Training Loss')
plt.plot(history2.history['val_loss'], label='Validation Loss')
plt.title('model_2 Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history2.history['accuracy'], label='Training Accuracy')
plt.plot(history2.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')

plt.tight_layout()
plt.show()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_73 (Dense)                │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_74 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_75 (Dense)                │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 118,282 (462.04 KB)
#  Trainable params: 118,282 (462.04 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.2031 - loss: 61416.8359 - val_accuracy: 0.5947 - val_loss: 297.3258
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6283 - loss: 264.5118 - val_accuracy: 0.7502 - val_loss: 158.7076
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7385 - loss: 172.7363 - val_accuracy: 0.7966 - val_loss: 123.8129
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7924 - loss: 127.8131 - val_accuracy: 0.8010 - val_loss: 122.2721
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8097 - loss: 113.7575 - val_accuracy: 0.8453 - val_loss: 92.0502
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8292 - loss: 105.2034 - val_accuracy: 0.8201 - val_loss: 120.8613
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8272 - loss: 104.4028 - val_accuracy: 0.8307 - val_loss: 108.3699
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8293 - loss: 113.2260 - val_accuracy: 0.8425 - val_loss: 101.9647
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8372 - loss: 106.2475 - val_accuracy: 0.8486 - val_loss: 106.1436
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8508 - loss: 97.7406 - val_accuracy: 0.8893 - val_loss: 70.0733

# %% [markdown]
# #### After providing your answer to the question above, please share your opinion on how to improve the performance of this model or address the issue described.

# %% [markdown]
# the performance became better with just changing activation function from sigmoid to relu

# %% [markdown]
# # Exploding Gradient

# %% [markdown]
# # Q4: What is the main cause of the Exploding gradient problem, and how can we solve it?

# %% [markdown]
# the main cause of explosion is the large value of update in weights in back probagation , this may happen when using wrong activation function and may happen when making large weight in initialization

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist

# Load the MNIST dataset
(X_train, y_train), (_, _) = mnist.load_data()

# Preprocess the data
X_train = X_train.reshape(-1, 784) / 255.0

# Create a simple neural network with two layers
model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, input_shape=(784,), activation='sigmoid'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy')

# Perform gradient explosion
for _ in range(10):
    with tf.GradientTape() as tape:
        predictions = model(X_train)
        loss = tf.reduce_mean(tf.keras.losses.sparse_categorical_crossentropy(y_train, predictions)) #reduce_mean compute the average loss across all the training samples

    gradients = tape.gradient(loss, model.trainable_variables)
    gradients = [tf.clip_by_value(grad, -5.0, 5.0) if grad is not None else grad for grad in gradients]
    model.optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    # Print the gradient norms
    gradient_norms = [tf.norm(grad).numpy() for grad in gradients]
    print("Gradient Norms:", gradient_norms)
# Out:
# Gradient Norms: [0.45742738, 0.06076502, 1.4383717, 0.17674899]
# Gradient Norms: [0.44492587, 0.05760406, 1.3687404, 0.16817522]
# Gradient Norms: [0.433996, 0.0547305, 1.304902, 0.16030638]
# Gradient Norms: [0.42435813, 0.052091733, 1.2457641, 0.15300846]
# Gradient Norms: [0.4157977, 0.049647152, 1.1905028, 0.14617988]
# Gradient Norms: [0.40814695, 0.047364887, 1.1384844, 0.13974369]
# Gradient Norms: [0.401273, 0.04521964, 1.089216, 0.13363868]
# Gradient Norms: [0.39506948, 0.04319117, 1.0423113, 0.12781718]
# Gradient Norms: [0.38945055, 0.041263238, 0.99746674, 0.12224166]
# Gradient Norms: [0.3843467, 0.039422844, 0.95444447, 0.11688319]

# %% [markdown]
# ## "Please provide proof of the effectiveness of your solution. How does it impact the results?" print here all Gradient term before and after add your solution

# %% [markdown]
# before
# Gradient Norms: [0.45742738, 0.06076502, 1.4383717, 0.17674899]
# Gradient Norms: [0.44492587, 0.05760406, 1.3687404, 0.16817522]
# Gradient Norms: [0.433996, 0.0547305, 1.304902, 0.16030638]
# Gradient Norms: [0.42435813, 0.052091733, 1.2457641, 0.15300846]
# Gradient Norms: [0.4157977, 0.049647152, 1.1905028, 0.14617988]
# Gradient Norms: [0.40814695, 0.047364887, 1.1384844, 0.13974369]
# Gradient Norms: [0.401273, 0.04521964, 1.089216, 0.13363868]
# Gradient Norms: [0.39506948, 0.04319117, 1.0423113, 0.12781718]
# Gradient Norms: [0.38945055, 0.041263238, 0.99746674, 0.12224166]
# Gradient Norms: [0.3843467, 0.039422844, 0.95444447, 0.11688319]
#
# ................................................................................

# %% [markdown]
# after
# Gradient Norms: [1.0307748, 0.09575492, 0.54118043, 0.08987426]
# Gradient Norms: [1.0176225, 0.093202405, 0.53022164, 0.08595066]
# Gradient Norms: [1.0053929, 0.09083114, 0.5201306, 0.08228611]
# Gradient Norms: [0.9943362, 0.088710554, 0.5108195, 0.078860775]
# Gradient Norms: [0.98403406, 0.08675386, 0.5022112, 0.075656265]
# Gradient Norms: [0.974412, 0.08497915, 0.49423903, 0.07265694]
# Gradient Norms: [0.9653925, 0.083319336, 0.48684597, 0.06984926]
# Gradient Norms: [0.9569808, 0.08183286, 0.47998106, 0.06722109]
# Gradient Norms: [0.9489658, 0.08045853, 0.4735991, 0.06476205]
# Gradient Norms: [0.94151664, 0.0791984, 0.46765906, 0.06246099]
#
# ...........................................

# %% [markdown]
# i see that there wasn't explosion in the first code or the modified one as gradient values were decreasing
# ................................................................................

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist

# Load the MNIST dataset
(X_train, y_train), (_, _) = mnist.load_data()

# Preprocess the data
X_train = X_train.reshape(-1, 784) / 255.0

# Create a simple neural network with two layers
model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, input_shape=(784,), activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy')

# Perform gradient explosion
for _ in range(10):
    with tf.GradientTape() as tape:
        predictions = model(X_train)
        loss = tf.reduce_mean(tf.keras.losses.sparse_categorical_crossentropy(y_train, predictions)) #reduce_mean compute the average loss across all the training samples

    gradients = tape.gradient(loss, model.trainable_variables)
    gradients = [tf.clip_by_value(grad, -1.0, 1.0) if grad is not None else grad for grad in gradients]
    model.optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    # Print the gradient norms
    gradient_norms = [tf.norm(grad).numpy() for grad in gradients]
    print("Gradient Norms:", gradient_norms)
# Out:
# Gradient Norms: [1.0307748, 0.09575492, 0.54118043, 0.08987426]
# Gradient Norms: [1.0176225, 0.093202405, 0.53022164, 0.08595066]
# Gradient Norms: [1.0053929, 0.09083114, 0.5201306, 0.08228611]
# Gradient Norms: [0.9943362, 0.088710554, 0.5108195, 0.078860775]
# Gradient Norms: [0.98403406, 0.08675386, 0.5022112, 0.075656265]
# Gradient Norms: [0.974412, 0.08497915, 0.49423903, 0.07265694]
# Gradient Norms: [0.9653925, 0.083319336, 0.48684597, 0.06984926]
# Gradient Norms: [0.9569808, 0.08183286, 0.47998106, 0.06722109]
# Gradient Norms: [0.9489658, 0.08045853, 0.4735991, 0.06476205]
# Gradient Norms: [0.94151664, 0.0791984, 0.46765906, 0.06246099]

# %% [markdown]
# # Q5: Provide proof of the effectiveness of adding a Dropout layer to the model. Additionally, provide a brief description of how Dropout works and its impact on model performance.

# %% [markdown]
# ..................................................................

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist

# Load the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Preprocess the data
X_train = X_train.reshape(-1, 784) / 255.0
X_test = X_test.reshape(-1, 784) / 255.0

# Create a simple neural network without Dropout
model_with_dropout = tf.keras.Sequential([
    tf.keras.layers.Dense(100, input_shape=(784,), activation='relu'),
    tf.keras.layers.Dense(100, activation='relu'),


    tf.keras.layers.Dense(10, activation='softmax')
])
# Compile the model
model_without_dropout.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history_without_dropout = model_without_dropout.fit(X_train, y_train, epochs=20, batch_size=48, validation_data=(X_test, y_test))
# Out:
# c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9597 - loss: 0.1449 - val_accuracy: 0.9571 - val_loss: 0.1463
# Epoch 2/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9610 - loss: 0.1436 - val_accuracy: 0.9578 - val_loss: 0.1424
# Epoch 3/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9613 - loss: 0.1411 - val_accuracy: 0.9590 - val_loss: 0.1384
# Epoch 4/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9623 - loss: 0.1351 - val_accuracy: 0.9600 - val_loss: 0.1337
# Epoch 5/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9643 - loss: 0.1287 - val_accuracy: 0.9619 - val_loss: 0.1297
# Epoch 6/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9662 - loss: 0.1224 - val_accuracy: 0.9633 - val_loss: 0.1281
# Epoch 7/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9675 - loss: 0.1189 - val_accuracy: 0.9631 - val_loss: 0.1246
# Epoch 8/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9688 - loss: 0.1167 - val_accuracy: 0.9641 - val_loss: 0.1216
# Epoch 9/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9687 - loss: 0.1144 - val_accuracy: 0.9649 - val_loss: 0.1197
# Epoch 10/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9702 - loss: 0.1105 - val_accuracy: 0.9661 - val_loss: 0.1160
# Epoch 11/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9708 - loss: 0.1074 - val_accuracy: 0.9660 - val_loss: 0.1129
# Epoch 12/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9718 - loss: 0.1031 - val_accuracy: 0.9672 - val_loss: 0.1103
# Epoch 13/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9723 - loss: 0.0992 - val_accuracy: 0.9682 - val_loss: 0.1092
# Epoch 14/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9738 - loss: 0.0973 - val_accuracy: 0.9688 - val_loss: 0.1072
# Epoch 15/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9726 - loss: 0.0958 - val_accuracy: 0.9691 - val_loss: 0.1051
# Epoch 16/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9744 - loss: 0.0942 - val_accuracy: 0.9697 - val_loss: 0.1038
# Epoch 17/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9762 - loss: 0.0876 - val_accuracy: 0.9698 - val_loss: 0.1018
# Epoch 18/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9769 - loss: 0.0855 - val_accuracy: 0.9699 - val_loss: 0.0997
# Epoch 19/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9772 - loss: 0.0841 - val_accuracy: 0.9702 - val_loss: 0.0981
# Epoch 20/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9777 - loss: 0.0864 - val_accuracy: 0.9714 - val_loss: 0.0968

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist

# Load the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Preprocess the data
X_train = X_train.reshape(-1, 784) / 255.0
X_test = X_test.reshape(-1, 784) / 255.0

# Create a simple neural network with Dropout
model_with_dropout = tf.keras.Sequential([
    tf.keras.layers.Dense(100, input_shape=(784,), activation='relu'),
    tf.keras.layers.Dropout(0.5),  # Dropout layer with 50% rate
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dropout(0.5),  # Dropout layer with 50% rate


    tf.keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model_with_dropout.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history_with_dropout = model_with_dropout.fit(X_train, y_train, epochs=20, batch_size=48, validation_data=(X_test, y_test))
# Out:
# Epoch 1/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3736 - loss: 1.8065 - val_accuracy: 0.8763 - val_loss: 0.5304
# Epoch 2/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7410 - loss: 0.8194 - val_accuracy: 0.9058 - val_loss: 0.3605
# Epoch 3/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8099 - loss: 0.6231 - val_accuracy: 0.9163 - val_loss: 0.3029
# Epoch 4/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8381 - loss: 0.5379 - val_accuracy: 0.9237 - val_loss: 0.2700
# Epoch 5/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8553 - loss: 0.4879 - val_accuracy: 0.9262 - val_loss: 0.2491
# Epoch 6/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8693 - loss: 0.4476 - val_accuracy: 0.9323 - val_loss: 0.2303
# Epoch 7/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8755 - loss: 0.4256 - val_accuracy: 0.9360 - val_loss: 0.2220
# Epoch 8/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8854 - loss: 0.4003 - val_accuracy: 0.9386 - val_loss: 0.2100
# Epoch 9/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8896 - loss: 0.3835 - val_accuracy: 0.9411 - val_loss: 0.1998
# Epoch 10/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8965 - loss: 0.3654 - val_accuracy: 0.9446 - val_loss: 0.1911
# Epoch 11/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8991 - loss: 0.3458 - val_accuracy: 0.9465 - val_loss: 0.1878
# Epoch 12/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9057 - loss: 0.3347 - val_accuracy: 0.9484 - val_loss: 0.1803
# Epoch 13/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9072 - loss: 0.3234 - val_accuracy: 0.9498 - val_loss: 0.1734
# Epoch 14/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9070 - loss: 0.3211 - val_accuracy: 0.9512 - val_loss: 0.1678
# Epoch 15/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9115 - loss: 0.3067 - val_accuracy: 0.9506 - val_loss: 0.1647
# Epoch 16/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9147 - loss: 0.2986 - val_accuracy: 0.9520 - val_loss: 0.1604
# Epoch 17/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9184 - loss: 0.2893 - val_accuracy: 0.9530 - val_loss: 0.1561
# Epoch 18/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9207 - loss: 0.2875 - val_accuracy: 0.9538 - val_loss: 0.1525
# Epoch 19/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9180 - loss: 0.2881 - val_accuracy: 0.9562 - val_loss: 0.1507
# Epoch 20/20
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9197 - loss: 0.2816 - val_accuracy: 0.9565 - val_loss: 0.1478

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history_without_dropout.history['val_accuracy'], label='Without Dropout')
plt.plot(history_with_dropout.history['val_accuracy'], label='With Dropout')
plt.title('Model Accuracy with and without Dropout')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history_without_dropout.history['val_loss'], label='Without Dropout')
plt.plot(history_with_dropout.history['val_loss'], label='With Dropout')
plt.title('Model Loss with and without Dropout')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# | Dropout    | Accuracy       |
# |------------|----------------|
# | Before     |       0.9777          |
# | After      |     0.9197            |
#
# dropput is a technique used to prevent overfitiing in neural networks .the basic idea of drop out is drop some percipreons in back neurons this make model shift aliitle bit from the target.
# this may cause less accuracy  but it helps to get rid of over fitting  and less training time

# %% [markdown]
# # Q6 Regarding Q2, after enhancing the model, please provide proof of the differences in performance for each activation function used. Compare the results for each activation function to demonstrate how they affect the model's performance.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import LeakyReLU
import matplotlib.pyplot as plt

# Load the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Preprocess the data
X_train = X_train.reshape(-1, 784) / 255.0
X_test = X_test.reshape(-1, 784) / 255.0

def create_model(activation):
    """ Creates a model with the specified activation function """
    model = tf.keras.Sequential([
        Dense(100, input_shape=(784,), activation=activation),
        Dense(100, activation=activation),
        Dense(10, activation='softmax')
    ])
    model.compile(optimizer=RMSprop(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Create models for each activation function
activation_functions = ['relu', 'sigmoid', 'tanh', LeakyReLU(), 'elu']
history_dict = {}

for activation in activation_functions:
    model = create_model(activation)
    print(f"Training with activation: {activation}")
    history = model.fit(X_train, y_train, epochs=20, batch_size=48, validation_data=(X_test, y_test), verbose=0)
    history_dict[activation] = history
    print(f"model accuracy with activation: {activation} is ",history.history['val_accuracy'][-1])
    

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
for activation in activation_functions:
    plt.plot(history_dict[activation].history['val_accuracy'], label=f'{activation}')
plt.title('Model Accuracy with Different Activation Functions')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(12, 6))
for activation in activation_functions:
    plt.plot(history_dict[activation].history['val_loss'], label=f'{activation}')
plt.title('Model Loss with Different Activation Functions')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')
plt.show()
# Out:
# c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training with activation: relu
# model accuracy with activation: relu is  0.9783999919891357
# Training with activation: sigmoid
# model accuracy with activation: sigmoid is  0.9768000245094299
# Training with activation: tanh
# model accuracy with activation: tanh is  0.9765999913215637
# Training with activation: <LeakyReLU name=leaky_re_lu_1, built=False>
# model accuracy with activation: <LeakyReLU name=leaky_re_lu_1, built=True> is  0.978600025177002
# Training with activation: elu
# model accuracy with activation: elu is  0.9787999987602234

# %% [markdown]
# | Activation Function | Accuracy |
# |---------------------|----------|
# | ReLU                |0.9783999919891357          |
# | Sigmoid             |0.9768000245094299          |
# | Tanh                |0.9765999913215637          |
# | Leaky ReLU          |0.978600025177002          |
# | ELU (Exponential Linear Unit) |0.9787999987602234  |

# %% [markdown]
# # Q7: What is the best approach for improving model performance: adding more hidden layers or increasing the number of nodes per hidden layer? Please provide code examples to support your suggestions.

# %% [markdown]
# after trying with code , we found that increasing number of nodes per layer made better result iin accuracy than adding more layers

# %%
import tensorflow as tf

# Define the Functional API model
def create_model(optimizer='adam', learning_rate=0.01):
    # Input layer
    inputs = tf.keras.Input(shape=(784,))
    
    # Hidden layer
    x = tf.keras.layers.Dense(100, activation='relu')(inputs)
    # Hidden layer2
    outputs = tf.keras.layers.Dense(10, activation='softmax')(x)
    
    # Create model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    
    # Configure the model
    opt = tf.keras.optimizers.get(optimizer)
    opt.learning_rate = learning_rate
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# Create the model using the Functional API
model = create_model(optimizer='adam', learning_rate=0.001)

# Train the model
history = model.fit(X_train, y_train_oh, epochs=30, batch_size=48, validation_split=0.3)

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(X_test, y_test_oh,batch_size=5)
print(f"Test accuracy: {test_acc}")
# Out:
# Epoch 1/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8443 - loss: 0.5708 - val_accuracy: 0.9422 - val_loss: 0.2012
# Epoch 2/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9498 - loss: 0.1704 - val_accuracy: 0.9564 - val_loss: 0.1534
# Epoch 3/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9669 - loss: 0.1145 - val_accuracy: 0.9626 - val_loss: 0.1269
# Epoch 4/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9740 - loss: 0.0884 - val_accuracy: 0.9667 - val_loss: 0.1160
# Epoch 5/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9802 - loss: 0.0661 - val_accuracy: 0.9679 - val_loss: 0.1104
# Epoch 6/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9847 - loss: 0.0557 - val_accuracy: 0.9692 - val_loss: 0.1065
# Epoch 7/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9883 - loss: 0.0434 - val_accuracy: 0.9692 - val_loss: 0.1044
# Epoch 8/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9909 - loss: 0.0339 - val_accuracy: 0.9715 - val_loss: 0.0984
# Epoch 9/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9919 - loss: 0.0296 - val_accuracy: 0.9720 - val_loss: 0.1005
# Epoch 10/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9934 - loss: 0.0237 - val_accuracy: 0.9725 - val_loss: 0.0979
# Epoch 11/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9959 - loss: 0.0178 - val_accuracy: 0.9717 - val_loss: 0.1027
# Epoch 12/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9961 - loss: 0.0156 - val_accuracy: 0.9720 - val_loss: 0.1060
# Epoch 13/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9979 - loss: 0.0122 - val_accuracy: 0.9737 - val_loss: 0.1073
# Epoch 14/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9983 - loss: 0.0096 - val_accuracy: 0.9707 - val_loss: 0.1144
# Epoch 15/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9981 - loss: 0.0092 - val_accuracy: 0.9701 - val_loss: 0.1246
# Epoch 16/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9978 - loss: 0.0086 - val_accuracy: 0.9725 - val_loss: 0.1168
# Epoch 17/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9977 - loss: 0.0086 - val_accuracy: 0.9733 - val_loss: 0.1120
# Epoch 18/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9996 - loss: 0.0041 - val_accuracy: 0.9720 - val_loss: 0.1259
# Epoch 19/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9980 - loss: 0.0079 - val_accuracy: 0.9736 - val_loss: 0.1211
# Epoch 20/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9997 - loss: 0.0034 - val_accuracy: 0.9743 - val_loss: 0.1232
# Epoch 21/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9984 - loss: 0.0065 - val_accuracy: 0.9714 - val_loss: 0.1295
# Epoch 22/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9991 - loss: 0.0045 - val_accuracy: 0.9755 - val_loss: 0.1214
# Epoch 23/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9999 - loss: 0.0016 - val_accuracy: 0.9755 - val_loss: 0.1205
# Epoch 24/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9990 - loss: 0.0038 - val_accuracy: 0.9717 - val_loss: 0.1515
# Epoch 25/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9986 - loss: 0.0047 - val_accuracy: 0.9733 - val_loss: 0.1377
# Epoch 26/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9999 - loss: 0.0016 - val_accuracy: 0.9738 - val_loss: 0.1332
# Epoch 27/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 6.3833e-04 - val_accuracy: 0.9749 - val_loss: 0.1322
# Epoch 28/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9990 - loss: 0.0038 - val_accuracy: 0.9686 - val_loss: 0.1635
# Epoch 29/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9977 - loss: 0.0070 - val_accuracy: 0.9737 - val_loss: 0.1433
# Epoch 30/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 9.0147e-04 - val_accuracy: 0.9742 - val_loss: 0.1381
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9757 - loss: 0.1267
# Test accuracy: 0.9787999987602234

# %%
import tensorflow as tf

# Define the Functional API model
def create_model(optimizer='adam', learning_rate=0.01):
    # Input layer
    inputs = tf.keras.Input(shape=(784,))
    
    # Hidden layer
    x = tf.keras.layers.Dense(20, activation='relu')(inputs)
        # Hidden layer
    x1 = tf.keras.layers.Dense(30, activation='relu')(x)
        # Hidden layer
    x2 = tf.keras.layers.Dense(30, activation='relu')(x1)
        # Hidden layer
    x3 = tf.keras.layers.Dense(20, activation='relu')(x2)
    # Hidden layer2
    outputs = tf.keras.layers.Dense(10, activation='softmax')(x3)
    
    # Create model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    
    # Configure the model
    opt = tf.keras.optimizers.get(optimizer)
    opt.learning_rate = learning_rate
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# Create the model using the Functional API
model = create_model(optimizer='adam', learning_rate=0.001)

# Train the model
history = model.fit(X_train, y_train_oh, epochs=30, batch_size=48, validation_split=0.3)

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(X_test, y_test_oh,batch_size=5)
print(f"Test accuracy: {test_acc}")
# Out:
# Epoch 1/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7107 - loss: 0.9335 - val_accuracy: 0.9182 - val_loss: 0.2828
# Epoch 2/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9237 - loss: 0.2632 - val_accuracy: 0.9311 - val_loss: 0.2406
# Epoch 3/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9370 - loss: 0.2143 - val_accuracy: 0.9317 - val_loss: 0.2300
# Epoch 4/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9479 - loss: 0.1752 - val_accuracy: 0.9453 - val_loss: 0.1906
# Epoch 5/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9553 - loss: 0.1523 - val_accuracy: 0.9439 - val_loss: 0.1889
# Epoch 6/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9585 - loss: 0.1371 - val_accuracy: 0.9452 - val_loss: 0.1872
# Epoch 7/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9622 - loss: 0.1254 - val_accuracy: 0.9514 - val_loss: 0.1671
# Epoch 8/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9630 - loss: 0.1157 - val_accuracy: 0.9526 - val_loss: 0.1675
# Epoch 9/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9674 - loss: 0.1074 - val_accuracy: 0.9524 - val_loss: 0.1601
# Epoch 10/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9710 - loss: 0.0967 - val_accuracy: 0.9547 - val_loss: 0.1593
# Epoch 11/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9716 - loss: 0.0922 - val_accuracy: 0.9506 - val_loss: 0.1720
# Epoch 12/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9719 - loss: 0.0884 - val_accuracy: 0.9532 - val_loss: 0.1646
# Epoch 13/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9737 - loss: 0.0827 - val_accuracy: 0.9527 - val_loss: 0.1704
# Epoch 14/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9778 - loss: 0.0750 - val_accuracy: 0.9567 - val_loss: 0.1621
# Epoch 15/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9771 - loss: 0.0731 - val_accuracy: 0.9559 - val_loss: 0.1597
# Epoch 16/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9795 - loss: 0.0673 - val_accuracy: 0.9521 - val_loss: 0.1804
# Epoch 17/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9792 - loss: 0.0635 - val_accuracy: 0.9562 - val_loss: 0.1660
# Epoch 18/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9793 - loss: 0.0632 - val_accuracy: 0.9551 - val_loss: 0.1728
# Epoch 19/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9829 - loss: 0.0556 - val_accuracy: 0.9576 - val_loss: 0.1656
# Epoch 20/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9834 - loss: 0.0521 - val_accuracy: 0.9509 - val_loss: 0.1944
# Epoch 21/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9833 - loss: 0.0541 - val_accuracy: 0.9568 - val_loss: 0.1795
# Epoch 22/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9848 - loss: 0.0513 - val_accuracy: 0.9553 - val_loss: 0.1858
# Epoch 23/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9840 - loss: 0.0474 - val_accuracy: 0.9552 - val_loss: 0.1794
# Epoch 24/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9844 - loss: 0.0478 - val_accuracy: 0.9560 - val_loss: 0.1816
# Epoch 25/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9856 - loss: 0.0456 - val_accuracy: 0.9547 - val_loss: 0.1956
# Epoch 26/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9841 - loss: 0.0473 - val_accuracy: 0.9563 - val_loss: 0.1920
# Epoch 27/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9862 - loss: 0.0427 - val_accuracy: 0.9542 - val_loss: 0.2135
# Epoch 28/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9864 - loss: 0.0421 - val_accuracy: 0.9554 - val_loss: 0.1966
# Epoch 29/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9875 - loss: 0.0359 - val_accuracy: 0.9552 - val_loss: 0.2050
# Epoch 30/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9876 - loss: 0.0385 - val_accuracy: 0.9554 - val_loss: 0.1976
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9553 - loss: 0.2088
# Test accuracy: 0.9596999883651733

# %% [markdown]
# to make sure that all input data are the same range to make sure that there arenot vanishing or exploding values and also that make model faster if all values are less than 1
# ....................................................................

# %% [markdown]
# # Q9 What is batch normalization, and why is it used in neural network training? Describe how batch normalization impacts the learning process and its benefits for training deep networks

# %% [markdown]
# Batch normalization is a technique used in training deep neural networks to improve the speed, performance, and stability of the training process. It normalizes the inputs to a layer for each mini-batch during training,
#  It helps stabilize and accelerate the training process by ensuring that the inputs to each layer are normalized to have a consistent distribution.
# ..................................................................

# %% [markdown]
# # How does batch normalization assist in training deep neural networks? Share your observations and insights after applying batch normalization to your model architecture. If you did not use batch normalization, explain why and provide evidence to support your decision."

# %% [markdown]
# .........................................

# %%
import tensorflow as tf

# Define the Functional API model
def create_model(optimizer='adam', learning_rate=0.01):
    # Input layer
    inputs = tf.keras.Input(shape=(784,))
    
    # Hidden layer
    x = tf.keras.layers.Dense(20, activation='relu')(inputs)
        # Hidden layer
    x1 = tf.keras.layers.Dense(30, activation='relu')(x)
        # Hidden layer
    x2 = tf.keras.layers.Dense(30, activation='relu')(x1)
        # Hidden layer
    x3 = tf.keras.layers.Dense(20, activation='relu')(x2)
    # Hidden layer2
    outputs = tf.keras.layers.Dense(10, activation='softmax')(x3)
    
    # Create model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    
    # Configure the model
    opt = tf.keras.optimizers.get(optimizer)
    opt.learning_rate = learning_rate
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# Create the model using the Functional API
model = create_model(optimizer='adam', learning_rate=0.001)

# Train the model
history = model.fit(X_train, y_train_oh, epochs=30, batch_size=48, validation_split=0.3)

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(X_test, y_test_oh,batch_size=5)
print(f"Test accuracy: {test_acc}")
# Out:
# Epoch 1/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6776 - loss: 0.9800 - val_accuracy: 0.9150 - val_loss: 0.2783
# Epoch 2/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9262 - loss: 0.2492 - val_accuracy: 0.9319 - val_loss: 0.2322
# Epoch 3/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9433 - loss: 0.1900 - val_accuracy: 0.9417 - val_loss: 0.1976
# Epoch 4/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9540 - loss: 0.1546 - val_accuracy: 0.9483 - val_loss: 0.1756
# Epoch 5/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9566 - loss: 0.1410 - val_accuracy: 0.9521 - val_loss: 0.1635
# Epoch 6/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9634 - loss: 0.1194 - val_accuracy: 0.9524 - val_loss: 0.1618
# Epoch 7/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9659 - loss: 0.1144 - val_accuracy: 0.9527 - val_loss: 0.1596
# Epoch 8/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9700 - loss: 0.1010 - val_accuracy: 0.9468 - val_loss: 0.1806
# Epoch 9/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9714 - loss: 0.0946 - val_accuracy: 0.9558 - val_loss: 0.1559
# Epoch 10/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9724 - loss: 0.0909 - val_accuracy: 0.9527 - val_loss: 0.1650
# Epoch 11/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9725 - loss: 0.0845 - val_accuracy: 0.9551 - val_loss: 0.1591
# Epoch 12/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9764 - loss: 0.0790 - val_accuracy: 0.9536 - val_loss: 0.1617
# Epoch 13/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9784 - loss: 0.0693 - val_accuracy: 0.9569 - val_loss: 0.1578
# Epoch 14/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9792 - loss: 0.0656 - val_accuracy: 0.9577 - val_loss: 0.1547
# Epoch 15/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9803 - loss: 0.0638 - val_accuracy: 0.9564 - val_loss: 0.1699
# Epoch 16/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9800 - loss: 0.0641 - val_accuracy: 0.9577 - val_loss: 0.1612
# Epoch 17/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9816 - loss: 0.0581 - val_accuracy: 0.9563 - val_loss: 0.1676
# Epoch 18/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9828 - loss: 0.0542 - val_accuracy: 0.9581 - val_loss: 0.1641
# Epoch 19/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9839 - loss: 0.0505 - val_accuracy: 0.9562 - val_loss: 0.1772
# Epoch 20/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9830 - loss: 0.0506 - val_accuracy: 0.9554 - val_loss: 0.1704
# Epoch 21/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9860 - loss: 0.0448 - val_accuracy: 0.9537 - val_loss: 0.1839
# Epoch 22/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9859 - loss: 0.0437 - val_accuracy: 0.9590 - val_loss: 0.1738
# Epoch 23/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9856 - loss: 0.0438 - val_accuracy: 0.9587 - val_loss: 0.1757
# Epoch 24/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9867 - loss: 0.0413 - val_accuracy: 0.9566 - val_loss: 0.1921
# Epoch 25/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9881 - loss: 0.0377 - val_accuracy: 0.9576 - val_loss: 0.1820
# Epoch 26/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9884 - loss: 0.0366 - val_accuracy: 0.9533 - val_loss: 0.2015
# Epoch 27/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9856 - loss: 0.0443 - val_accuracy: 0.9570 - val_loss: 0.1943
# Epoch 28/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9891 - loss: 0.0343 - val_accuracy: 0.9549 - val_loss: 0.2137
# Epoch 29/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9888 - loss: 0.0345 - val_accuracy: 0.9564 - val_loss: 0.2023
# Epoch 30/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9900 - loss: 0.0316 - val_accuracy: 0.9546 - val_loss: 0.2085
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9514 - loss: 0.2224
# Test accuracy: 0.9562000036239624

# %%
import tensorflow as tf

# Define the Functional API model
def create_model(optimizer='adam', learning_rate=0.01):
    # Input layer
    inputs = tf.keras.Input(shape=(784,))
    
    # Hidden layer
    x = tf.keras.layers.Dense(20, activation='relu')(inputs)
    tf.keras.layers.BatchNormalization(),  # Batch Normalization

        # Hidden layer
    x1 = tf.keras.layers.Dense(30, activation='relu')(x)
    tf.keras.layers.BatchNormalization(),  # Batch Normalization

        # Hidden layer
    x2 = tf.keras.layers.Dense(30, activation='relu')(x1)
    tf.keras.layers.BatchNormalization(),  # Batch Normalization

        # Hidden layer
    x3 = tf.keras.layers.Dense(20, activation='relu')(x2)
    tf.keras.layers.BatchNormalization(),  # Batch Normalization

    # Hidden layer2
    outputs = tf.keras.layers.Dense(10, activation='softmax')(x3)
    tf.keras.layers.BatchNormalization(),  # Batch Normalization

    
    # Create model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    
    # Configure the model
    opt = tf.keras.optimizers.get(optimizer)
    opt.learning_rate = learning_rate
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# Create the model using the Functional API
model = create_model(optimizer='adam', learning_rate=0.001)

# Train the model
history = model.fit(X_train, y_train_oh, epochs=30, batch_size=48, validation_split=0.3)

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(X_test, y_test_oh,batch_size=5)
print(f"Test accuracy: {test_acc}")
# Out:
# Epoch 1/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6996 - loss: 0.8952 - val_accuracy: 0.9201 - val_loss: 0.2805
# Epoch 2/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9258 - loss: 0.2508 - val_accuracy: 0.9352 - val_loss: 0.2276
# Epoch 3/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9401 - loss: 0.2001 - val_accuracy: 0.9399 - val_loss: 0.2048
# Epoch 4/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9513 - loss: 0.1653 - val_accuracy: 0.9465 - val_loss: 0.1876
# Epoch 5/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9562 - loss: 0.1488 - val_accuracy: 0.9470 - val_loss: 0.1850
# Epoch 6/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9608 - loss: 0.1313 - val_accuracy: 0.9462 - val_loss: 0.1815
# Epoch 7/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9641 - loss: 0.1209 - val_accuracy: 0.9484 - val_loss: 0.1786
# Epoch 8/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9645 - loss: 0.1166 - val_accuracy: 0.9472 - val_loss: 0.1859
# Epoch 9/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9676 - loss: 0.1031 - val_accuracy: 0.9482 - val_loss: 0.1821
# Epoch 10/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9691 - loss: 0.0984 - val_accuracy: 0.9543 - val_loss: 0.1637
# Epoch 11/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9719 - loss: 0.0938 - val_accuracy: 0.9498 - val_loss: 0.1785
# Epoch 12/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9744 - loss: 0.0861 - val_accuracy: 0.9534 - val_loss: 0.1681
# Epoch 13/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9746 - loss: 0.0794 - val_accuracy: 0.9504 - val_loss: 0.1766
# Epoch 14/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9752 - loss: 0.0797 - val_accuracy: 0.9550 - val_loss: 0.1683
# Epoch 15/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9775 - loss: 0.0738 - val_accuracy: 0.9522 - val_loss: 0.1775
# Epoch 16/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9790 - loss: 0.0689 - val_accuracy: 0.9532 - val_loss: 0.1740
# Epoch 17/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9794 - loss: 0.0653 - val_accuracy: 0.9497 - val_loss: 0.1959
# Epoch 18/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9794 - loss: 0.0664 - val_accuracy: 0.9543 - val_loss: 0.1768
# Epoch 19/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9804 - loss: 0.0596 - val_accuracy: 0.9556 - val_loss: 0.1747
# Epoch 20/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9818 - loss: 0.0571 - val_accuracy: 0.9527 - val_loss: 0.1870
# Epoch 21/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9813 - loss: 0.0592 - val_accuracy: 0.9551 - val_loss: 0.1716
# Epoch 22/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9818 - loss: 0.0560 - val_accuracy: 0.9547 - val_loss: 0.1806
# Epoch 23/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9833 - loss: 0.0529 - val_accuracy: 0.9534 - val_loss: 0.1863
# Epoch 24/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9837 - loss: 0.0527 - val_accuracy: 0.9566 - val_loss: 0.1873
# Epoch 25/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9839 - loss: 0.0507 - val_accuracy: 0.9540 - val_loss: 0.1913
# Epoch 26/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9827 - loss: 0.0492 - val_accuracy: 0.9508 - val_loss: 0.2126
# Epoch 27/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9854 - loss: 0.0454 - val_accuracy: 0.9526 - val_loss: 0.2065
# Epoch 28/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9867 - loss: 0.0439 - val_accuracy: 0.9546 - val_loss: 0.2027
# Epoch 29/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9860 - loss: 0.0410 - val_accuracy: 0.9561 - val_loss: 0.1974
# Epoch 30/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9859 - loss: 0.0417 - val_accuracy: 0.9537 - val_loss: 0.2143
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9507 - loss: 0.2042
# Test accuracy: 0.9559000134468079

# %% [markdown]
# | batch normalization | Accuracy |
# |---------------------|----------|
# | Before              |    0.9514       |
# | After               |  0.9592000246047974        |

# %% [markdown]
# # Advanced Part (optional)

# %% [markdown]
# # Convert your TensorFlow model to PyTorch. Provide the PyTorch code equivalent of your TensorFlow model, ensuring that the architecture, hyperparameters, and any custom layers or functionalities are correctly translated."

# %%
import tensorflow as tf

# Define the Functional API model
def create_model(optimizer='adam', learning_rate=0.01):
    # Input layer
    inputs = tf.keras.Input(shape=(784,))
    
    # Hidden layer
    x = tf.keras.layers.Dense(100, activation='relu')(inputs)
    # Hidden layer2
    outputs = tf.keras.layers.Dense(10, activation='softmax')(x)
    
    # Create model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    
    # Configure the model
    opt = tf.keras.optimizers.get(optimizer)
    opt.learning_rate = learning_rate
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# Create the model using the Functional API
model = create_model(optimizer='adam', learning_rate=0.001)

# Train the model
history = model.fit(X_train, y_train_oh, epochs=30, batch_size=48, validation_split=0.3)

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(X_test, y_test_oh,batch_size=5)
print(f"Test accuracy: {test_acc}")
# Out:
# Epoch 1/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8401 - loss: 0.5860 - val_accuracy: 0.9411 - val_loss: 0.2069
# Epoch 2/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9527 - loss: 0.1683 - val_accuracy: 0.9576 - val_loss: 0.1503
# Epoch 3/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9663 - loss: 0.1160 - val_accuracy: 0.9609 - val_loss: 0.1302
# Epoch 4/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9756 - loss: 0.0869 - val_accuracy: 0.9674 - val_loss: 0.1133
# Epoch 5/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9813 - loss: 0.0669 - val_accuracy: 0.9682 - val_loss: 0.1079
# Epoch 6/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9856 - loss: 0.0520 - val_accuracy: 0.9706 - val_loss: 0.1036
# Epoch 7/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9885 - loss: 0.0416 - val_accuracy: 0.9671 - val_loss: 0.1150
# Epoch 8/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9902 - loss: 0.0368 - val_accuracy: 0.9718 - val_loss: 0.1010
# Epoch 9/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9921 - loss: 0.0281 - val_accuracy: 0.9707 - val_loss: 0.1091
# Epoch 10/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9936 - loss: 0.0251 - val_accuracy: 0.9715 - val_loss: 0.1027
# Epoch 11/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9960 - loss: 0.0173 - val_accuracy: 0.9703 - val_loss: 0.1087
# Epoch 12/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9958 - loss: 0.0166 - val_accuracy: 0.9696 - val_loss: 0.1142
# Epoch 13/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9977 - loss: 0.0123 - val_accuracy: 0.9726 - val_loss: 0.1057
# Epoch 14/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9979 - loss: 0.0103 - val_accuracy: 0.9728 - val_loss: 0.1098
# Epoch 15/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9979 - loss: 0.0101 - val_accuracy: 0.9719 - val_loss: 0.1159
# Epoch 16/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9980 - loss: 0.0083 - val_accuracy: 0.9724 - val_loss: 0.1155
# Epoch 17/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9983 - loss: 0.0074 - val_accuracy: 0.9734 - val_loss: 0.1142
# Epoch 18/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9990 - loss: 0.0054 - val_accuracy: 0.9726 - val_loss: 0.1248
# Epoch 19/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9986 - loss: 0.0066 - val_accuracy: 0.9731 - val_loss: 0.1199
# Epoch 20/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9984 - loss: 0.0071 - val_accuracy: 0.9730 - val_loss: 0.1281
# Epoch 21/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9996 - loss: 0.0032 - val_accuracy: 0.9742 - val_loss: 0.1213
# Epoch 22/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9988 - loss: 0.0046 - val_accuracy: 0.9720 - val_loss: 0.1342
# Epoch 23/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9993 - loss: 0.0037 - val_accuracy: 0.9741 - val_loss: 0.1289
# Epoch 24/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9999 - loss: 0.0017 - val_accuracy: 0.9736 - val_loss: 0.1315
# Epoch 25/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9973 - loss: 0.0082 - val_accuracy: 0.9731 - val_loss: 0.1380
# Epoch 26/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9990 - loss: 0.0034 - val_accuracy: 0.9722 - val_loss: 0.1478
# Epoch 27/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9989 - loss: 0.0045 - val_accuracy: 0.9745 - val_loss: 0.1321
# Epoch 28/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9999 - loss: 9.3714e-04 - val_accuracy: 0.9742 - val_loss: 0.1387
# Epoch 29/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9983 - loss: 0.0057 - val_accuracy: 0.9721 - val_loss: 0.1501
# Epoch 30/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9993 - loss: 0.0031 - val_accuracy: 0.9742 - val_loss: 0.1461
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9730 - loss: 0.1357
# Test accuracy: 0.9765999913215637

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

# Define the PyTorch model
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        # Define layers
        self.fc1 = nn.Linear(784, 100)  # Hidden layer
        self.fc2 = nn.Linear(100, 10)   # Output layer
    
    def forward(self, x):
        x = F.relu(self.fc1(x))  # Hidden layer with ReLU activation
        x = F.softmax(self.fc2(x), dim=1)  # Output layer with softmax
        return x

# Initialize the model
model = SimpleNN()

# Set optimizer and loss function
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# Prepare your dataset (Assuming X_train and y_train are in numpy arrays)
train_data = torch.tensor(X_train, dtype=torch.float32)
train_labels = torch.tensor(y_train, dtype=torch.long)  # PyTorch expects labels as longs
train_dataset = TensorDataset(train_data, train_labels)
train_loader = DataLoader(train_dataset, batch_size=48, shuffle=True)

# Train the model
epochs = 30
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for i, (inputs, labels) in enumerate(train_loader):
        optimizer.zero_grad()  # Zero gradients
        outputs = model(inputs)  # Forward pass
        loss = criterion(outputs, labels)  # Compute loss
        loss.backward()  # Backpropagation
        optimizer.step()  # Optimize
        
        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)
    
    epoch_loss = running_loss / len(train_loader)
    epoch_acc = 100 * correct / total
    print(f"Epoch [{epoch+1}/{epochs}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.2f}%")

# Evaluate the model on the test set
model.eval()
test_data = torch.tensor(X_test, dtype=torch.float32)
test_labels = torch.tensor(y_test, dtype=torch.long)
test_outputs = model(test_data)
_, test_predicted = torch.max(test_outputs, 1)
test_acc = (test_predicted == test_labels).sum().item() / len(test_labels)
print(f"Test accuracy: {test_acc:.2f}")
# Out:
# Epoch [1/30], Loss: 1.6080, Accuracy: 87.76%
# Epoch [2/30], Loss: 1.5327, Accuracy: 93.55%
# Epoch [3/30], Loss: 1.5167, Accuracy: 94.95%
# Epoch [4/30], Loss: 1.5072, Accuracy: 95.78%
# Epoch [5/30], Loss: 1.5002, Accuracy: 96.44%
# Epoch [6/30], Loss: 1.4949, Accuracy: 96.96%
# Epoch [7/30], Loss: 1.4907, Accuracy: 97.30%
# Epoch [8/30], Loss: 1.4878, Accuracy: 97.60%
# Epoch [9/30], Loss: 1.4846, Accuracy: 97.91%
# Epoch [10/30], Loss: 1.4827, Accuracy: 98.06%
# Epoch [11/30], Loss: 1.4805, Accuracy: 98.25%
# Epoch [12/30], Loss: 1.4791, Accuracy: 98.39%
# Epoch [13/30], Loss: 1.4778, Accuracy: 98.50%
# Epoch [14/30], Loss: 1.4768, Accuracy: 98.60%
# Epoch [15/30], Loss: 1.4757, Accuracy: 98.69%
# Epoch [16/30], Loss: 1.4747, Accuracy: 98.80%
# Epoch [17/30], Loss: 1.4739, Accuracy: 98.85%
# Epoch [18/30], Loss: 1.4733, Accuracy: 98.89%
# Epoch [19/30], Loss: 1.4725, Accuracy: 98.97%
# Epoch [20/30], Loss: 1.4723, Accuracy: 98.99%
# Epoch [21/30], Loss: 1.4717, Accuracy: 99.05%
# Epoch [22/30], Loss: 1.4715, Accuracy: 99.05%
# Epoch [23/30], Loss: 1.4711, Accuracy: 99.08%
# Epoch [24/30], Loss: 1.4705, Accuracy: 99.16%
# Epoch [25/30], Loss: 1.4706, Accuracy: 99.12%
# Epoch [26/30], Loss: 1.4700, Accuracy: 99.20%
# Epoch [27/30], Loss: 1.4696, Accuracy: 99.23%
# Epoch [28/30], Loss: 1.4696, Accuracy: 99.20%
# Epoch [29/30], Loss: 1.4693, Accuracy: 99.24%
# Epoch [30/30], Loss: 1.4692, Accuracy: 99.25%
# Test accuracy: 0.98

# %% [markdown]
# # Finally, print the accuracy for each model architecture. Discuss with your team the differences observed in accuracy across various architectures, and analyze the potential reasons behind these variations."

# %% [markdown]
# Test accuracy: 0.9765999913215637 in tensorflow
# Test accuracy: 0.98 in pytorch
#
# both results are appromixatly the same

# %% [markdown]
# # Callback

# %% [markdown]
# ### search for Callback method In TensorFlow and Keras, a callback is a set of functions that can be applied at various stages of the training process, allowing you to customize the behavior of the training loop. Callbacks provide a way to monitor and intervene during training, enabling features

# %%
import tensorflow as tf

# Define the Functional API model
def create_model(optimizer='adam', learning_rate=0.001):
    # Input layer
    inputs = tf.keras.Input(shape=(784,))
    
    # Hidden layer
    x = tf.keras.layers.Dense(100, activation='relu')(inputs)
    
    # Output layer
    outputs = tf.keras.layers.Dense(10, activation='softmax')(x)
    
    # Create the model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    
    # Set the optimizer with the given learning rate
    opt = tf.keras.optimizers.get(optimizer)
    opt.learning_rate = learning_rate
    
    # Compile the model
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# # # # Learning rate scheduler function
# # # def scheduler(epoch, lr):
# # #     if epoch < 10:
# # #         return lr
# # #     else:
# # #         return lr * 0.1  # Reduce learning rate after 10 epochs

# Initialize the model
model = create_model(optimizer='adam', learning_rate=0.001)

# Define callbacks
# # # early_stopping = tf.keras.callbacks.EarlyStopping(
# # #     monitor='val_accuracy',      # Monitor validation accuracy
# # #     patience=5,              # Stop after 3 epochs of no improvement
# # #     restore_best_weights=True  # Restore the best weights after stopping
# # # )

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath='model_checkpoint.keras',  # Filepath to save the best model
    save_best_only=True,             # Save only the best model
    monitor='val_accuracy'               # Monitor validation loss
)

# # # lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',  # Monitor validation loss
    factor=0.2,          # Reduce learning rate by 20%
    patience=5,          # Wait for 3 epochs with no improvement
    min_lr=0.001         # Set minimum learning rate
)

# Create a list of callbacks to pass to model.fit
###callbacks = [early_stopping, checkpoint, lr_scheduler, reduce_lr]
###callbacks = [checkpoint, lr_scheduler, reduce_lr]
callbacks = [checkpoint, reduce_lr]

# Train the model
history = model.fit(
    X_train, y_train_oh,
    epochs=30,
    batch_size=48,
    validation_split=0.3,
    callbacks=callbacks  # Pass the callbacks
)

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(X_test, y_test_oh, batch_size=5)
print(f"Test accuracy: {test_acc}")
# Out:
# Epoch 1/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8402 - loss: 0.5759 - val_accuracy: 0.9410 - val_loss: 0.1999 - learning_rate: 0.0010
# Epoch 2/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9522 - loss: 0.1655 - val_accuracy: 0.9562 - val_loss: 0.1522 - learning_rate: 0.0010
# Epoch 3/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9678 - loss: 0.1125 - val_accuracy: 0.9641 - val_loss: 0.1282 - learning_rate: 0.0010
# Epoch 4/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9759 - loss: 0.0845 - val_accuracy: 0.9639 - val_loss: 0.1238 - learning_rate: 0.0010
# Epoch 5/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9826 - loss: 0.0648 - val_accuracy: 0.9687 - val_loss: 0.1043 - learning_rate: 0.0010
# Epoch 6/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9860 - loss: 0.0519 - val_accuracy: 0.9652 - val_loss: 0.1151 - learning_rate: 0.0010
# Epoch 7/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9895 - loss: 0.0397 - val_accuracy: 0.9693 - val_loss: 0.1061 - learning_rate: 0.0010
# Epoch 8/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9903 - loss: 0.0345 - val_accuracy: 0.9711 - val_loss: 0.1050 - learning_rate: 0.0010
# Epoch 9/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9911 - loss: 0.0297 - val_accuracy: 0.9718 - val_loss: 0.1006 - learning_rate: 0.0010
# Epoch 10/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9950 - loss: 0.0222 - val_accuracy: 0.9699 - val_loss: 0.1117 - learning_rate: 0.0010
# Epoch 11/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9955 - loss: 0.0199 - val_accuracy: 0.9696 - val_loss: 0.1142 - learning_rate: 0.0010
# Epoch 12/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9953 - loss: 0.0180 - val_accuracy: 0.9726 - val_loss: 0.1063 - learning_rate: 0.0010
# Epoch 13/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9974 - loss: 0.0123 - val_accuracy: 0.9724 - val_loss: 0.1084 - learning_rate: 0.0010
# Epoch 14/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9980 - loss: 0.0101 - val_accuracy: 0.9716 - val_loss: 0.1200 - learning_rate: 0.0010
# Epoch 15/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9979 - loss: 0.0095 - val_accuracy: 0.9724 - val_loss: 0.1119 - learning_rate: 0.0010
# Epoch 16/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9989 - loss: 0.0072 - val_accuracy: 0.9682 - val_loss: 0.1329 - learning_rate: 0.0010
# Epoch 17/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9978 - loss: 0.0090 - val_accuracy: 0.9719 - val_loss: 0.1230 - learning_rate: 0.0010
# Epoch 18/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9990 - loss: 0.0054 - val_accuracy: 0.9710 - val_loss: 0.1300 - learning_rate: 0.0010
# Epoch 19/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9984 - loss: 0.0071 - val_accuracy: 0.9723 - val_loss: 0.1231 - learning_rate: 0.0010
# Epoch 20/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9988 - loss: 0.0051 - val_accuracy: 0.9734 - val_loss: 0.1260 - learning_rate: 0.0010
# Epoch 21/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9992 - loss: 0.0043 - val_accuracy: 0.9721 - val_loss: 0.1355 - learning_rate: 0.0010
# Epoch 22/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9989 - loss: 0.0044 - val_accuracy: 0.9742 - val_loss: 0.1319 - learning_rate: 0.0010
# Epoch 23/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9993 - loss: 0.0033 - val_accuracy: 0.9738 - val_loss: 0.1313 - learning_rate: 0.0010
# Epoch 24/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9757 - val_loss: 0.1282 - learning_rate: 0.0010
# Epoch 25/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 0.9652 - val_loss: 0.1799 - learning_rate: 0.0010
# Epoch 26/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9945 - loss: 0.0150 - val_accuracy: 0.9723 - val_loss: 0.1489 - learning_rate: 0.0010
# Epoch 27/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9993 - loss: 0.0030 - val_accuracy: 0.9743 - val_loss: 0.1359 - learning_rate: 0.0010
# Epoch 28/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 6.6933e-04 - val_accuracy: 0.9748 - val_loss: 0.1389 - learning_rate: 0.0010
# Epoch 29/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 3.7410e-04 - val_accuracy: 0.9754 - val_loss: 0.1392 - learning_rate: 0.0010
# Epoch 30/30
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 1.0000 - loss: 3.1211e-04 - val_accuracy: 0.9748 - val_loss: 0.1412 - learning_rate: 0.0010
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9748 - loss: 0.1237
# Test accuracy: 0.9764999747276306

# %% [markdown]
# # Tensorboard!!!!!!

# %% [markdown]
# ## Review the following code and provide a detailed explanation of how it works. Describe each section and its purpose, and explain how the code achieves its intended functionality.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# Load and preprocess the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape(-1, 784) / 255.0
X_test = X_test.reshape(-1, 784) / 255.0

# Split data into training and validation sets
X_val, X_train = X_train[:10000], X_train[10000:]
y_val, y_train = y_train[:10000], y_train[10000:]

##this function is to create model
def create_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(128, activation='relu', input_shape=(784,)),
        tf.keras.layers.Dense(10, activation='softmax')
    ])
    return model
##this function is to train and evaluate model
def train_and_evaluate(optimizer, X_train, y_train, X_val, y_val):
    model = create_model()
    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    history = model.fit(X_train, y_train, 
                        epochs=10, 
                        validation_data=(X_val, y_val),
                        verbose=0)
    
    val_accuracy = history.history['val_accuracy'][-1]
    return val_accuracy

# Define different optimizers
optimizers = {
    'SGD': tf.keras.optimizers.SGD(),
    'Momentum': tf.keras.optimizers.SGD(momentum=0.9),
    'RMSprop': tf.keras.optimizers.RMSprop(),
    'AdaDelta': tf.keras.optimizers.Adadelta(),
    'Adagrad': tf.keras.optimizers.Adagrad(),
    'Adam': tf.keras.optimizers.Adam()
}

# Train and evaluate models with different optimizers
results = {}
## for loop to train model with diffrent optimisers
for name, optimizer in optimizers.items():
    accuracy = train_and_evaluate(optimizer, X_train, y_train, X_val, y_val)
    results[name] = accuracy

# Print results
for name, accuracy in results.items():
    print(f"Optimizer: {name}, Validation Accuracy: {accuracy:.4f}")
# Out:
# c:\Users\workstation\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Optimizer: SGD, Validation Accuracy: 0.9471
# Optimizer: Momentum, Validation Accuracy: 0.9767
# Optimizer: RMSprop, Validation Accuracy: 0.9767
# Optimizer: AdaDelta, Validation Accuracy: 0.7522
# Optimizer: Adagrad, Validation Accuracy: 0.9061
# Optimizer: Adam, Validation Accuracy: 0.9795

# %%
# Plotting the results
names = list(results.keys())
accuracies = list(results.values())

plt.figure(figsize=(10, 6))
plt.bar(names, accuracies, color='skyblue')
plt.xlabel('Optimizer')
plt.ylabel('Validation Accuracy')
plt.title('Comparison of Optimizers')
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# # Anothe challenge

# %% [markdown]
# # In this dataset, all deep learning architectures attempted so far have resulted in overfitting. Explore and apply various techniques to mitigate overfitting, such as regularization, dropout, data augmentation, and early stopping. Please provide feedback on the effectiveness of each method and summarize your results.

# %% [markdown]
# # Dataset Description
#
# This dataset contains information related to students in an educational context. It includes various demographic, behavioral, and academic features, which can be used to analyze student performance and engagement. The dataset consists of the following attributes:
#
# - **gender:** The gender of the student (e.g., male, female).
# - **NationalITy:** The nationality of the student, which may influence educational outcomes.
# - **PlaceofBirth:** The geographic location where the student was born, providing insights into potential cultural and socio-economic factors.
# - **StageID:** The educational stage or level the student is currently in (e.g., primary, secondary).
# - **GradeID:** The grade or year the student is enrolled in, indicating their progress in the education system.
# - **SectionID:** The specific section or class within a grade that the student belongs to.
# - **Topic:** The subject or topic of study, relevant for performance analysis in specific areas.
# - **Semester:** The semester in which the data was collected, which may affect academic performance and engagement.
# - **Relation:** The relationship of the student with their parents (e.g., mother, father), potentially influencing support and academic outcomes.
# - **raisedhands:** The number of times the student raised their hands in class, indicating participation and engagement.
# - **VisITedResources:** The number of educational resources the student has accessed, which reflects their engagement with the material.
# - **AnnouncementsView:** The number of times the student viewed announcements from the school, suggesting their awareness of important updates.
# - **Discussion:** The level of participation in discussions, indicating engagement in collaborative learning.
# - **ParentAnsweringSurvey:** Responses from parents in a survey, which may provide insights into parental involvement.
# - **ParentschoolSatisfaction:** The satisfaction level of parents with the school, which could correlate with student performance.
# - **StudentAbsenceDays:** The number of days the student was absent, which can impact learning outcomes.
# - **Class:** The target variable indicating the student's performance category or final grade, often used for classification tasks.
#
# **Challenges:** The dataset may exhibit challenges such as class imbalance, varying levels of engagement among students, and the influence of external factors on academic performance.
#
# This dataset is suitable for analysis aimed at understanding student behavior, predicting academic outcomes, and identifying factors contributing to student success or challenges.

# %%
import numpy as np
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
import os

import pandas as pd
import seaborn as sns
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_recall_fscore_support

from matplotlib import pyplot as plt
import seaborn as sns

data = pd.read_csv('Dataset.csv')


data.loc[data["Class"] == "L", "Class"] = 0
data.loc[data["Class"] == "M", "Class"] = 1
data.loc[data["Class"] == "H", "Class"] = 2
##display(data)
##print(data.columns)

# Separate features and target
X = data.drop('Class', axis=1)
y = data['Class']

# Apply OneHotEncoder to categorical features
categorical_columns = ['gender', 'NationalITy', 'PlaceofBirth', 'StageID', 'GradeID', 'SectionID', 'Topic', 'Semester', 
                       'Relation', 'ParentAnsweringSurvey', 'ParentschoolSatisfaction', 'StudentAbsenceDays']
numerical_columns = ['raisedhands', 'VisITedResources', 'AnnouncementsView', 'Discussion']


encoder = OneHotEncoder(sparse_output=False)
X_encoded = encoder.fit_transform(X[categorical_columns])


# Scale numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X[numerical_columns])


# Combine scaled numerical and encoded categorical features
X_preprocessed = np.hstack((X_scaled, X_encoded))




# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.1, random_state=42)

# Convert the labels into float32 (binary classification scenario)
y_train = y_train.astype(np.float32)
y_test = y_test.astype(np.float32)

def create_model(optimizer='adam', learning_rate=0.001):
    # Input layer
    inputs = tf.keras.Input(shape=(X_train.shape[1],))
    tf.keras.layers.BatchNormalization(),  # Batch Normalization
    
    # Hidden layer
    x = tf.keras.layers.Dense(1000, activation='sigmoid')(inputs)
    tf.keras.layers.Dropout(0.3),  # Dropout layer with 50% rate
    tf.keras.layers.BatchNormalization(),  # Batch Normalization

    
    # Hidden layer
    x1 = tf.keras.layers.Dense(1000, activation='sigmoid')(x)
    tf.keras.layers.Dropout(0.3),  # Dropout layer with 50% rate
    tf.keras.layers.BatchNormalization(),  # Batch Normalization

    # Hidden layer
    x2 = tf.keras.layers.Dense(1000, activation='sigmoid')(x1)
    tf.keras.layers.Dropout(0.3),  # Dropout layer with 50% rate
    tf.keras.layers.BatchNormalization(),  # Batch Normalization

    # Output layer
    outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x2)
    
    # Create the model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    
    # Set the optimizer with the given learning rate
    opt = tf.keras.optimizers.get(optimizer)
    opt.learning_rate = learning_rate
    
    # Compile the model
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

# Define the model
model =create_model() 

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy', patience=10, restore_best_weights=True
)
#model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, validation_split=0.2, epochs=30, batch_size=5, callbacks=[early_stopping])

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(X_test, y_test ,batch_size=2)
print(f"Test Accuracy: {test_acc:.4f}")


# Plot training & validation loss values
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('model_2 Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='lower right')

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/30
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.3963 - loss: -0.0606 - val_accuracy: 0.4598 - val_loss: -1.6212
# Epoch 2/30
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.4312 - loss: -5.3311 - val_accuracy: 0.5977 - val_loss: -11.3186
# Epoch 3/30
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.5856 - loss: -15.0069 - val_accuracy: 0.6437 - val_loss: -19.8077
# Epoch 4/30
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.6202 - loss: -21.2791 - val_accuracy: 0.6092 - val_loss: -27.6489
# Epoch 5/30
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.6287 - loss: -31.7229 - val_accuracy: 0.6092 - val_loss: -34.6166
# Epoch 6/30
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.6307 - loss: -36.9691 - val_accuracy: 0.6207 - val_loss: -42.3111
# Epoch 7/30
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5835 - loss: -46.8113 - val_accuracy: 0.6092 - val_loss: -51.3096
# Epoch 8/30
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.6331 - loss: -54.1598 - val_accuracy: 0.6322 - val_loss: -59.4197
# Epoch 9/30
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.6523 - loss: -63.8287 - val_accuracy: 0.6322 - val_loss: -67.3490
# Epoch 10/30
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.6020 - loss: -63.8462 - val_accuracy: 0.6322 - val_loss: -74.3773
# Epoch 11/30
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.6198 - loss: -82.5698 - val_accuracy: 0.6207 - val_loss: -81.7932
# Epoch 12/30
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.6346 - loss: -81.4233 - val_accuracy: 0.6322 - val_loss: -91.3168
# Epoch 13/30
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.6274 - loss: -100.7619 - val_accuracy: 0.6207 - val_loss: -96.8870
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4801 - loss: -21.5578
# Test Accuracy: 0.6042
